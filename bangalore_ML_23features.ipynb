# %% [markdown]
# ### Loading the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the dataset containing information of BANGALORE cars

# %%
df=pd.read_csv('cleaned_bangalore_cars.csv')
df.head()
# Out:
#    Unnamed: 0  id   car_from  it      ft         bt        km transmission  \
# 0           0   0  bangalore   0  Petrol  Hatchback  1,20,000       Manual
# 1           1   1  bangalore   0  Petrol        SUV    32,706       Manual
# 2           2   2  bangalore   0  Petrol  Hatchback    11,949       Manual
# 3           3   3  bangalore   0  Petrol      Sedan    17,794       Manual
# 4           4   4  bangalore   0  Diesel        SUV    60,000       Manual
#
#    ownerNo      owner  ... Turbo Charger Turning Radius         Tyre Type  \
# 0        3  3rd Owner  ...            No     4.7 metres  Tubeless, Radial
# 1        2  2nd Owner  ...            No     5.3 metres   Tubeless,Radial
# 2        1  1st Owner  ...            No     4.9 meters          Tubeless
# 3        1  1st Owner  ...            No     4.7 metres   Tubeless,Radial
# 4        1  1st Owner  ...           Yes     5.2 meters   Tubeless,Radial
#
#    Value Configuration Values per Cylinder Wheel Base Wheel Size   Width   d  \
# 0                 DOHC                 4.0     2425mm        NaN  1635mm NaN
# 1                 DOHC                 4.0     2519mm         16  1765mm NaN
# 2                 DOHC                 4.0     2400mm         14  1647mm NaN
# 3                 DOHC                 4.0     2425mm         14  1660mm NaN
# 4                 DOHC                 4.0     2600mm         16  1785mm NaN
#
#   id.3
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
#
# [5 rows x 248 columns]

# %%
df.shape
# Out:
# (1481, 248)

# %%
len(df.columns)
# Out:
# 248

# %% [markdown]
# ### Segragating categorical and numerical columns

# %%
#categorical columns list
all_cc=[]
#numerical columns list
all_nc=[]
for i in df.columns:
    if df[i].dtype=='O':
        all_cc.append(i)
    else:
        all_nc.append(i)
print('categorical_columns:',all_cc)
print()
print('numerical_columns:',all_nc)
# Out:
# categorical_columns: ['car_from', 'ft', 'bt', 'km', 'transmission', 'owner', 'oem', 'model', 'variantName', 'price', 'priceActual', 'trendingText_heading', 'trendingText_desc', 'Registration Year', 'Insurance Validity', 'Fuel Type', 'Seats', 'Kms Driven', 'RTO', 'Ownership', 'Engine Displacement', 'Transmission', 'Acceleration', 'Alloy Wheel Size', 'BoreX Stroke', 'Cargo Volumn', 'Color', 'Compression Ratio', 'Drive Type', 'Engine', 'Engine Type', 'Front Brake Type', 'Front Tread', 'Fuel Suppy System', 'Gear Box', 'Gross Weight', 'Ground Clearance Unladen', 'Height', 'Kerb Weight', 'Length', 'Max Power', 'Max Torque', 'Mileage', 'Rear Brake Type', 'Rear Tread', 'Steering Type', 'Super Charger', 'Top Speed', 'Torque', 'Turbo Charger', 'Turning Radius', 'Tyre Type', 'Value Configuration', 'Wheel Base', 'Wheel Size', 'Width']
#
# numerical_columns: ['Unnamed: 0', 'id', 'it', 'ownerNo', 'modelYear', 'centralVariantId', 'priceSaving', 'priceFixedText', 'id.1', 'Year of Manufacture', 'Accessory Power Outlet', 'Active Noise Cancellation', 'Adjustable Head Lights', 'Adjustable Headrest', 'Adjustable Seats', 'Adjustable Steering', 'Air Conditioner', 'Air Quality Control', 'Alloy Wheels', 'Android Auto', 'Anti Lock Braking System', 'Anti Pinch Power Windows', 'Anti Theft Alarm', 'Anti Theft Device', 'Apple Car Play', 'Audio System Remote Control', 'Automatic Driving Lights', 'Automatic Head Lamps', 'Battery Saver', 'Blind Spot Monitor', 'Bluetooth', 'Brake Assist', 'Cassette Player', 'Cd Changer', 'Cd Player', 'Centeral Locking', 'Centrally Mounted Fuel Tank', 'Child Safety Locks', 'Chrome Garnish', 'Chrome Grille', 'Cigarette Lighter', 'Clutch Lock', 'Compass', 'Cornering Foglamps', 'Cornering Headlamps', 'Crash Sensor', 'Cruise Control', 'Cup Holders Front', 'Cup Holders Rear', 'Day Night Rear View Mirror', 'Digital Clock', 'Digital Odometer', 'Door Ajar Warning', 'Drive Modes', 'Driver Air Bag', 'Driving Experience Control Eco', 'Dual Tone Body Colour', 'Dual Tone Dashboard', 'Dvd Player', 'Ebd', 'Electric Folding Rear View Mirror', 'Electronic Multi Tripmeter', 'Eletronic Stability Control', 'Engine Check Warning', 'Engine Immobilizer', 'Engine Start Stop Button', 'Fabric Upholstery', 'Find My Car Location', 'Fog Lights Front', 'Fog Lights Rear', 'Follow Me Home Headlamps', 'Front Impact Beams', 'Gear Shift Indicator', 'Geo Fence Alert', 'Glove Box Cooling', 'Glove Compartment', 'Halogen Headlamps', 'Hands Free Tailgate', 'Headlamp Washers', 'Heads Up Display', 'Heated Wing Mirror', 'Heater', 'Height Adjustable Driver Seat', 'Height Adjustable Front Seat Belts', 'Hill Assist', 'Hill Descent Control', 'Impact Sensing Auto Door Lock', 'Integrated Antenna', 'Integrated2Din Audio', 'Internal Storage', 'Isofix Child Seat Mounts', 'Keyless Entry', 'Knee Airbags', 'LEDDRLs', 'LEDFog Lamps', 'LEDHeadlights', 'LEDTaillights', 'Lane Change Indicator', 'Lane Watch Camera', 'Leather Seats', 'Leather Steering Wheel', 'Leather Wrap Gear Shift Selector', 'Low Fuel Warning Light', 'Luggage Hook And Net', 'Manually Adjustable Exterior Rear View Mirror', 'Mirror Link', 'Moon Roof', 'Multifunction Steering Wheel', 'Navigation System', 'No Of Airbags', 'Number Of Speaker', 'Outside Rear View Mirror Turn Indicators', 'Outside Temperature Display', 'Passenger Air Bag', 'Passenger Side Rear View Mirror', 'Power Adjustable Exterior Rear View Mirror', 'Power Antenna', 'Power Boot', 'Power Door Locks', 'Power Folding3rd Row Seat', 'Power Steering', 'Power Windows Front', 'Power Windows Rear', 'Pretensioners And Force Limiter Seatbelts', 'Projector Headlamps', 'Radio', 'Rain Sensing Wiper', 'Real Time Vehicle Tracking', 'Rear ACVents', 'Rear Camera', 'Rear Entertainment System', 'Rear Folding Table', 'Rear Reading Lamp', 'Rear Seat Belts', 'Rear Seat Centre Arm Rest', 'Rear Seat Headrest', 'Rear Spoiler', 'Rear Window Defogger', 'Rear Window Washer', 'Rear Window Wiper', 'Remote Climate Control', 'Remote Engine Start Stop', 'Remote Fuel Lid Opener', 'Remote Horn Light Control', 'Remote Trunk Opener', 'Removable Convertible Top', 'Roof Carrier', 'Roof Rail', 'Seat Belt Warning', 'Seat Lumbar Support', 'Side Air Bag Front', 'Side Air Bag Rear', 'Side Impact Beams', 'Side Stepper', 'Smart Access Card Entry', 'Smart Key Band', 'Smoke Headlamps', 'Sos Emergency Assistance', 'Speakers Front', 'Speakers Rear', 'Speed Alert', 'Speed Sensing Auto Door Lock', 'Steering Mounted Tripmeter', 'Steering Wheel Gearshift Paddles', 'Sun Roof', 'Tachometer', 'Tailgate Ajar', 'Tinted Glass', 'Touch Screen', 'Touch Screen Size', 'Traction Control', 'Trunk Light', 'Tyre Pressure Monitor', 'Usb Auxiliary Input', 'Vanity Mirror', 'Vehicle Stability Control System', 'Ventilated Seats', 'View360Camera', 'Voice Control', 'Wheel Covers', 'Wifi Connectivity', 'Wireless Phone Charging', 'Xenon Headlamps', 'id.2 ...

# %%
# I will use the features in the car_features list along with the features selected using SHAP analysis
car_features=['No Door Numbers', 'No of Cylinder','Values per Cylinder']

# %% [markdown]
# ### Engineering the 'price' column

# %%
x=list(df['price'].apply(lambda x :x.lower()))
am=[]
cu=[]
for i in x:
    try:
        if (i.endswith('e')):
            r=list(i)
            r1=r.index('c')
            am.append(round(float(i[2:r1-1])*10000000,0))
            cu.append(i[r1:])
        elif (i.endswith('h')):
            r=list(i)
            r1=r.index('l')
            am.append(round(float(i[2:r1-1])*100000,0))
            cu.append(i[r1:])
        else:
            d=list(i)
            e=[]
            for j in d:
                if j.isnumeric()==True:
                    e.append(j)
            am.append(float(''.join(e)))
            cu.append('thousand')
    except ValueError:
            am.append(np.nan)
            cu.append(np.nan)

# %%
#New price column - this will be the 'target' variable
df['price_new']=am

# %%
#Lets take a look at the original and preprocessed price columns
df[['price','price_new']].head()
# Out:
#          price  price_new
# 0     ₹ 4 Lakh   400000.0
# 1  ₹ 8.11 Lakh   811000.0
# 2  ₹ 5.85 Lakh   585000.0
# 3  ₹ 4.62 Lakh   462000.0
# 4  ₹ 7.90 Lakh   790000.0

# %% [markdown]
# ### Engineering the 'km' column

# %%
kms=[]
for i in list(df['km']):
    d=list(i)
    e=[]
    for j in d:
        if j.isnumeric()==True:
            e.append(j)
    kms.append(float(''.join(e)))

# %%
#new km column
df['kms']=kms

# %%
df[['kms','km','Kms Driven']]
# Out:
#            kms        km    Kms Driven
# 0     120000.0  1,20,000  1,20,000 Kms
# 1      32706.0    32,706    32,706 Kms
# 2      11949.0    11,949    11,949 Kms
# 3      17794.0    17,794    17,794 Kms
# 4      60000.0    60,000    60,000 Kms
# ...        ...       ...           ...
# 1476  156039.0  1,56,039  1,56,039 Kms
# 1477   56000.0    56,000    56,000 Kms
# 1478   42000.0    42,000    42,000 Kms
# 1479   93003.0    93,003    93,003 Kms
# 1480   36000.0    36,000    36,000 Kms
#
# [1481 rows x 3 columns]

# %% [markdown]
# ### Combining the selected features in the list 'all_selected_features'

# %%
all_selected_features=['bt','owner', 'oem','Registration Year','Engine Displacement',
      'Seating Capacity','Alloy Wheel Size','Turbo Charger', 'Engine',  'Front Brake Type',
 'Gear Box', 'Height', 'Kerb Weight', 'Length', 'Max Power', 
'Max Torque', 'Mileage', 'Rear Brake Type', 'Wheel Base','Width','kms','price_new']
for i in car_features:
    all_selected_features.append(i)

# %%
df=df[all_selected_features]
df.head()
# Out:
#           bt      owner      oem Registration Year Engine Displacement  \
# 0  Hatchback  3rd Owner   Maruti              2015              998 cc
# 1        SUV  2nd Owner     Ford          Feb 2018             1497 cc
# 2  Hatchback  1st Owner     Tata         Sept 2018             1199 cc
# 3      Sedan  1st Owner  Hyundai          Dec 2014             1197 cc
# 4        SUV  1st Owner   Maruti              2015             1248 cc
#
#    Seating Capacity Alloy Wheel Size Turbo Charger   Engine Front Brake Type  \
# 0               5.0              NaN            No   998 CC  Ventilated Disc
# 1               5.0               16            No  1497 CC  Ventilated Disc
# 2               5.0               14            No  1199 CC             Disc
# 3               5.0               14            No  1197 CC            Disc
# 4               5.0               16           Yes  1248 CC  Ventilated Disc
#
#    ...        Max Torque     Mileage Rear Brake Type Wheel Base   Width  \
# 0  ...      90Nm@3500rpm   23.1 kmpl            Drum     2425mm  1635mm
# 1  ...     150Nm@4500rpm     17 kmpl            Drum     2519mm  1765mm
# 2  ...     114Nm@3500rpm  23.84 kmpl            Drum     2400mm  1647mm
# 3  ...  113.75Nm@4000rpm   19.1 kmpl            Drum     2425mm  1660mm
# 4  ...     200Nm@1750rpm  23.65 kmpl      Solid Disc     2600mm  1785mm
#
#         kms price_new No Door Numbers No of Cylinder Values per Cylinder
# 0  120000.0  400000.0             5.0            3.0                 4.0
# 1   32706.0  811000.0             4.0            3.0                 4.0
# 2   11949.0  585000.0             5.0            3.0                 4.0
# 3   17794.0  462000.0             4.0            4.0                 4.0
# 4   60000.0  790000.0             5.0            4.0                 4.0
#
# [5 rows x 25 columns]

# %%
df_nv=pd.DataFrame({'dtypes':df.dtypes,'null_count':df.isnull().sum(),
              'unique_values':df.nunique(),
             'percent_of_null_values':df.isnull().mean()})
df_nv
# Out:
#                       dtypes  null_count  unique_values  \
# bt                    object           0              8
# owner                 object           0              5
# oem                   object           0             29
# Registration Year     object           0            179
# Engine Displacement   object           4             95
# Seating Capacity     float64           1              7
# Alloy Wheel Size      object         452             16
# Turbo Charger         object         193              6
# Engine                object           3            105
# Front Brake Type      object          21             17
# Gear Box              object          24             56
# Height                object          21            222
# Kerb Weight           object          14            468
# Length                object          21            241
# Max Power             object          16            279
# Max Torque            object          16            306
# Mileage               object          42            317
# Rear Brake Type       object          21             16
# Wheel Base            object          35            175
# Width                 object          21            197
# kms                  float64           0            816
# price_new            float64           0            672
# No Door Numbers      float64           2              4
# No of Cylinder       float64           6              8
# Values per Cylinder  float64          11              5
#
#                      percent_of_null_values
# bt                                 0.000000
# owner                              0.000000
# oem                                0.000000
# Registration Year                  0.000000
# Engine Displacement                0.002701
# Seating Capacity                   0.000675
# Alloy Wheel Size                   0.305199
# Turbo Charger                      0.130317
# Engine                             0.002026
# Front Brake Type                   0.014180
# Gear Box                           0.016205
# Height                             0.014180
# Kerb Weight                        0.009453
# Length                             0.014180
# Max Power                          0.010804
# Max Torque                         0.010804
# Mileage                            0.028359
# Rear Brake Type                    0.014180
# Wheel Base                         0.023633
# Width                              0.014180
# kms                                0.000000
# price_new                          0.000000
# No Door Numbers                    0.001350
# No of Cylinder                     0.004051
# Values per Cylinder                0.007427

# %% [markdown]
# **I will impute the columns having more than 30% missing values and drop null rows having less 3% missing values**

# %% [markdown]
# ### Engineering the 'bt' column and renaming the new column as 'body_type'

# %%
df['body_type']=df['bt'].apply(lambda x:str(x).lower())
df['body_type'].value_counts()
# Out:
# body_type
# hatchback        673
# suv              409
# sedan            337
# muv               51
# minivans           8
# coupe              1
# pickup trucks      1
# convertibles       1
# Name: count, dtype: int64

# %%
df['body_type']=['other' if i=='muv' or i=='minivans' or i=='hybrids' or i=='coupe'  else i for i in list(df['body_type'])]
df['body_type'].value_counts()
# Out:
# body_type
# hatchback        673
# suv              409
# sedan            337
# other             60
# pickup trucks      1
# convertibles       1
# Name: count, dtype: int64

# %% [markdown]
# ### Engineering the 'owner' column

# %%
df['owner']=df['owner'].apply(lambda x:x.lower())
df['owner'].value_counts()
# Out:
# owner
# 1st owner    893
# 2nd owner    460
# 3rd owner     95
# 4th owner     25
# 5th owner      8
# Name: count, dtype: int64

# %%
df['owner']=df['owner'].map({'0th owner':'no_owner','1st owner':'1_owner','2nd owner':'2_owners','3rd owner':'>2_owners','4th owner':'>2_owners','5th owner':'>2_owners'})
df['owner'].value_counts()
# Out:
# owner
# 1_owner      893
# 2_owners     460
# >2_owners    128
# Name: count, dtype: int64

# %% [markdown]
# ### Engineering the 'oem' column

# %%
df['oem']=df['oem'].apply(lambda x:x.lower())
df['oem'].value_counts()
# Out:
# oem
# maruti                373
# hyundai               313
# honda                 137
# mahindra               77
# tata                   67
# renault                67
# ford                   61
# volkswagen             60
# toyota                 53
# mercedes-benz          41
# bmw                    38
# skoda                  37
# kia                    27
# audi                   24
# jeep                   20
# mg                     13
# nissan                 13
# fiat                   10
# chevrolet              10
# jaguar                  8
# volvo                   7
# datsun                  6
# land rover              4
# citroen                 4
# mini                    3
# mitsubishi              3
# opel                    3
# mahindra ssangyong      1
# mahindra renault        1
# Name: count, dtype: int64

# %%
car_make=['mg','nissan','jeep','chevrolet','volvo','fiat','land rover','mitsubishi','mini','jaguar','isuzu','citroen',
          'mahindra renault','mahindra ssangyong','lexus']
df['oem']=['other' if i in car_make  else i for i in list(df['oem'])]
df['oem'].value_counts()
# Out:
# oem
# maruti           373
# hyundai          313
# honda            137
# other             97
# mahindra          77
# renault           67
# tata              67
# ford              61
# volkswagen        60
# toyota            53
# mercedes-benz     41
# bmw               38
# skoda             37
# kia               27
# audi              24
# datsun             6
# opel               3
# Name: count, dtype: int64

# %% [markdown]
# ### Engineering the 'Registration Year' column

# %%
df['registration_year']=df['Registration Year'].apply(lambda x:str(x).lower())
df['registration_year'].value_counts()[:10]
# Out:
# registration_year
# 2022    53
# 2018    45
# 2016    43
# 2021    40
# 2012    39
# 2015    34
# 2014    33
# 2010    31
# 2020    30
# 2019    28
# Name: count, dtype: int64

# %%
df['registration_year']=df['Registration Year'].apply(lambda x:x[-4:])
df['registration_year'].value_counts()
# Out:
# registration_year
# 2018    180
# 2016    176
# 2017    171
# 2019    117
# 2021    110
# 2015    106
# 2020    104
# 2014     96
# 2022     90
# 2012     70
# 2013     67
# 2010     46
# 2011     45
# 2009     28
# 2008     19
# 2006     13
# 2004     11
# 2023      9
# 2007      8
# ance      7
# 2005      4
# 2003      3
# 2002      1
# Name: count, dtype: int64

# %%
ry=['2007','2006','2005','2004','2003','2002',]
df['registration_year']=['before_2008' if i in ry  else i for i in list(df['registration_year'])]
df['registration_year']=['not_specified' if i=='ance' else i for i in list(df['registration_year'])]
df['registration_year'].value_counts()
# Out:
# registration_year
# 2018             180
# 2016             176
# 2017             171
# 2019             117
# 2021             110
# 2015             106
# 2020             104
# 2014              96
# 2022              90
# 2012              70
# 2013              67
# 2010              46
# 2011              45
# before_2008       40
# 2009              28
# 2008              19
# 2023               9
# not_specified      7
# Name: count, dtype: int64

# %% [markdown]
# ### Engineering the 'Seating Capacity' column

# %%
df['seating_capacity']=df['Seating Capacity'].apply(lambda x:str(x))
df['seating_capacity'].value_counts()
# Out:
# seating_capacity
# 5.0     1302
# 7.0      129
# 4.0       20
# 8.0       15
# 6.0       12
# 10.0       1
# nan        1
# 9.0        1
# Name: count, dtype: int64

# %%
df['seating_capacity']=df['seating_capacity'].map({'4.0':'4.0','5.0':'5.0','6.0':'6.0',
                                                      '7.0':'7.0',
                                                      '8.0':'>=8','9.0':'>=8','10.0':'>=8'})
df['seating_capacity'].value_counts()
# Out:
# seating_capacity
# 5.0    1302
# 7.0     129
# 4.0      20
# >=8      17
# 6.0      12
# Name: count, dtype: int64

# %%
df.fillna({'seating_capacity':'5.0'},inplace=True)

# %% [markdown]
# ### Engineering the 'Engine Displacement' column

# %%
df['engine_displacement']=df['Engine Displacement'].apply(lambda x:str(x).lower())
df['engine_displacement'].value_counts()[:50]
# Out:
# engine_displacement
# 1197 cc      319
# manual       124
# 998 cc       101
# 1199 cc       94
# 1497 cc       65
# 999 cc        60
# automatic     49
# 1498 cc       47
# 2179 cc       42
# 1248 cc       42
# 1591 cc       32
# 1198 cc       30
# 1995 cc       26
# 1396 cc       25
# 1461 cc       25
# 1956 cc       21
# 1462 cc       19
# 796 cc        18
# 1086 cc       18
# 1582 cc       17
# 1493 cc       16
# 1598 cc       16
# 1968 cc       16
# 2143 cc       15
# 1496 cc       13
# 1368 cc       12
# 2494 cc       11
# 1999 cc       10
# 2982 cc       10
# 1798 cc       10
# 1353 cc        9
# 2993 cc        7
# 1196 cc        7
# 1373 cc        6
# 1969 cc        6
# 1997 cc        6
# 1998 cc        6
# 2987 cc        6
# 1499 cc        6
# 814 cc         5
# 1451 cc        5
# 1298 cc        5
# 2967 cc        5
# 1991 cc        5
# 1950 cc        4
# 2755 cc        4
# 2354 cc        4
# 1399 cc        4
# 1341 cc        4
# nan            4
# Name: count, dtype: int64

# %%
df['engine_displacement']=df['Engine Displacement'].apply(lambda x:str(x).lower())
ed=[]
for i in list(df['engine_displacement']):
    d=list(i)
    e=[]
    if i=='nan':
        ed.append(np.nan)
    elif i=='automatic':
        ed.append(9)
    elif i=='manual':
        ed.append(6)
    else:
        for j in d:
            if j.isnumeric()==True:
                e.append(j)

        
        ed.append(float(''.join(e)))
        
print(len(ed))    
df['engine_displacement']=ed
print(df['engine_displacement'].value_counts().sort_values())
print(set(ed))
# Out:
# 1481
# engine_displacement
# 1586.0      1
# 1996.0      1
# 1364.0      1
# 3597.0      1
# 2200.0      1
#          ...
# 1497.0     65
# 1199.0     94
# 998.0     101
# 6.0       124
# 1197.0    319
# Name: count, Length: 95, dtype: int64
# {nan, 0.0, 6, 9, 3597.0, 1047.0, 1061.0, 1582.0, 1586.0, 1590.0, 1591.0, 1595.0, 1596.0, 1597.0, 1086.0, 1598.0, 72.0, 1108.0, 2143.0, 1120.0, 624.0, 3198.0, 2179.0, 2694.0, 2696.0, 2184.0, 2198.0, 2199.0, 2200.0, 1194.0, 1196.0, 1197.0, 1198.0, 1199.0, 2755.0, 1248.0, 1781.0, 1797.0, 1798.0, 1298.0, 796.0, 799.0, 814.0, 2354.0, 1330.0, 1332.0, 2362.0, 1341.0, 1353.0, 1364.0, 1368.0, 2393.0, 1373.0, 2400.0, 1896.0, 2925.0, 1390.0, 1389.0, 1395.0, 1396.0, 1397.0, 1399.0, 1405.0, 2967.0, 1950.0, 1956.0, 2982.0, 2987.0, 1451.0, 1968.0, 1969.0, 2993.0, 1461.0, 1462.0, 2494.0, 2496.0, 1984.0, 2498.0, 2499.0, 1991.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 1493.0, 1495.0, 1496.0, 1497.0, 1498.0, 1499.0, 2523.0, 993.0, 995.0, 998.0, 999.0}

# %%
sns.displot(df['engine_displacement'])
plt.show()
print('mean:',df['engine_displacement'].mean(),'median:',df['engine_displacement'].median())
# Out:
# mean: 1263.8171970209885 median: 1198.0

# %%
df.fillna({'engine_displacement':df['engine_displacement'].median()},inplace=True)

# %% [markdown]
# ### Engineering the 'Alloy Wheel Size' column

# %%
df['alloy_wheel_size']=df['Alloy Wheel Size'].apply(lambda x:str(x).lower())
df['alloy_wheel_size'].value_counts()
# Out:
# alloy_wheel_size
# nan    452
# 16     316
# 15     201
# 17     156
# 14     132
# 13      66
# 18      66
# r16     25
# 19      16
# r15     12
# 12      10
# r18      9
# r17      9
# 20       4
# r14      3
# r19      2
# 21       2
# Name: count, dtype: int64

# %%
al=[]
for i in list(df['alloy_wheel_size']):
    if i=='nan':
        al.append(np.nan)
    elif i[0]!='r':
        al.append(f'r{i}')
    else:
        al.append(i)
df['alloy_wheel_size']=al
df['alloy_wheel_size'].value_counts()
# Out:
# alloy_wheel_size
# r16    341
# r15    213
# r17    165
# r14    135
# r18     75
# r13     66
# r19     18
# r12     10
# r20      4
# r21      2
# Name: count, dtype: int64

# %%
df.fillna({'alloy_wheel_size':'r16'},inplace=True)

# %%
df['alloy_wheel_size'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Engineering the 'Turbo Charger' column

# %%
df['turbo_charger']=df['Turbo Charger'].apply(lambda x:str(x).lower())
print(df['turbo_charger'].value_counts())
# Out:
# turbo_charger
# no      745
# yes     535
# nan     193
# twin      8
# Name: count, dtype: int64

# %%
df.groupby(['body_type','turbo_charger'])['turbo_charger'].count().plot(kind='barh')
plt.show()

# %%
z=list(df[df['turbo_charger']=='nan']['body_type'])
z
# Out:
# ['hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'other',
#  'hatchback',
#  'suv',
#  'sedan',
#  'hatchback',
#  'sedan',
#  'sedan',
#  'sedan',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'suv',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'sedan',
#  'hatchback',
#  'other',
#  'hatchback',
#  'hatchback',
#  'other',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'hatchback',
#  'sedan',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'other',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'other',
#  'sedan',
#  'hatchback',
#  'suv',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'other',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'other',
#  'hatchback',
#  'hatchback',
#  'other',
#  'other',
#  'sedan',
#  'hatchback',
#  'sedan',
#  'sedan',
#  'hatchback',
#  'sedan',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'other',
#  'other',
#  'other',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'hatchback',
#  'other',
#  'other',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'other',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'sedan',
#  'sedan',
#  'sedan',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'suv',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'sedan',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'hatchback',
#  'suv',
#  'hatchback']

# %%
for h in range(len(z)):
    if z[h]=='suv' or z[h]=='other':
        df.loc[(df['body_type']==z[h]) & (df['turbo_charger'].isnull()),['turbo_charger']]='yes'
    elif z[h]=='hatchback' or z[h]=='sedan':
        df.loc[(df['body_type']==z[h]) & (df['turbo_charger'].isnull()),['turbo_charger']]='no'

# %%
df['turbo_charger'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Engineering the 'Front Brake Type' column

# %%
df.columns
# Out:
# Index(['bt', 'owner', 'oem', 'Registration Year', 'Engine Displacement',
#        'Seating Capacity', 'Alloy Wheel Size', 'Turbo Charger', 'Engine',
#        'Front Brake Type', 'Gear Box', 'Height', 'Kerb Weight', 'Length',
#        'Max Power', 'Max Torque', 'Mileage', 'Rear Brake Type', 'Wheel Base',
#        'Width', 'kms', 'price_new', 'No Door Numbers', 'No of Cylinder',
#        'Values per Cylinder', 'body_type', 'registration_year',
#        'seating_capacity', 'engine_displacement', 'alloy_wheel_size',
#        'turbo_charger'],
#       dtype='object')

# %%
df['front_brake_type']=df['Front Brake Type'].apply(lambda x:str(x).lower())
print(df['front_brake_type'].value_counts())
# Out:
# front_brake_type
# disc                      971
# ventilated disc           436
# nan                        21
# ventilated discs           15
# disc & caliper type        11
# disc                        9
# solid disc                  4
# ventilated disc             3
# disk                        3
# drum                        2
# electric parking brake      2
#  disc                       1
# disc, 236 mm                1
# multilateral disc           1
#  ventilated disc            1
# Name: count, dtype: int64

# %%
df['front_brake_type'].unique()
# Out:
# array(['ventilated disc', 'disc', 'disc ', ' disc', 'disc & caliper type',
#        'ventilated discs', 'ventilated disc ', 'nan', 'disc, 236 mm',
#        'multilateral disc', 'solid disc', 'disk', 'drum',
#        'electric parking brake', ' ventilated disc'], dtype=object)

# %%
df['front_brake_type']=df['front_brake_type'].map({'disc':'solid disc','ventilated disc':'ventilated discs',
                                                   'ventilated discs':'ventilated discs','disc ':'solid disc',
                                                   'solid disc':'solid disc','disk':'solid disc','ventilated disk':'ventilated discs',
                                                   'ventilated disc ':'ventilated discs','vantilated disc':'ventilated discs',
                                                   'ventlated disc':'ventilated discs','disc, 236 mm':'solid disc','nan':'solid disc',
                                                   'drum':'other','multilateral disc':'other','disc & caliper type':'other',
                                                   'booster assisted ventilated disc':'other','caliper ventilated disc':'other',
                                                   'abs':'other'})
print(df['front_brake_type'].value_counts())
# Out:
# front_brake_type
# solid disc          1009
# ventilated discs     454
# other                 14
# Name: count, dtype: int64

# %% [markdown]
# ### Engineering the 'Gear Box' column

# %%
df['gear_box']=df['Gear Box'].apply(lambda x:str(x).lower())
print(df['gear_box'].value_counts())
# Out:
# gear_box
# 5 speed                                            732
# 6 speed                                            201
# 5-speed                                            106
# 7 speed                                             56
# 6-speed                                             53
# 8 speed                                             41
# 4 speed                                             39
# cvt                                                 32
# 6 speed                                             27
# 5 speed                                             25
# nan                                                 24
# 5                                                   18
# 9 speed                                             15
# 7-speed dct                                         13
# 5 speed cvt                                         11
# 6-speed imt                                          8
# 7-speed                                              7
# five speed manual                                    6
# 8-speed steptronic                                   6
# 7 speed dct                                          6
# 6 speed imt                                          5
# 8-speed                                              4
# 8 speed tiptronic                                    4
# 8-speed                                              3
# 7 speed dsg                                          3
# direct drive                                         2
# 5-speed`                                             2
# ags                                                  2
# 7-speed s-tronic                                     2
# 6-speed dct                                          2
# imt                                                  2
# 7-speed s-tronic                                     2
# 8-speed steptronic sport automatic transmission      2
# 7 speed cvt                                          2
# 9-speed                                              2
# 6 speed at                                           1
# five speed manual transmission                       1
# 4-speed                                              1
# 6speed                                               1
# 8g-dct                                               1
# 6-speed autoshift                                    1
# 5 speed at+ paddle shifters                          1
# 8 speed cvt                                          1
# 7g dct 7-speed dual clutch transmission              1
# ivt                                                  1
# 6 speed ivt                                          1
# 6-speed cvt                                          1
# 6-speed ivt                                          1
# 9 speed tronic                                       1
# 6                                                    1
# 6 speed mt                                           1
# Name: count, dtype: int64

# %%
df['gear_box'].unique()
# Out:
# array(['5 speed ', '5 speed', '6 speed', '7-speed', '4 speed', '6 speed ',
#        '8g-dct', '5-speed', '7 speed', '9 speed', '8 speed',
#        '8-speed steptronic', '6-speed', '7-speed dct', '9-speed',
#        '8 speed tiptronic', '5', '6 speed imt', '6-speed autoshift',
#        '6-speed cvt', 'cvt', '7 speed dsg', '7 speed dct', '6', '8-speed',
#        '8-speed steptronic sport automatic transmission', '7 speed cvt',
#        'five speed manual', '5 speed cvt', 'nan', '6 speed at',
#        '6-speed imt', '6-speed dct', '7-speed s-tronic ',
#        '7g dct 7-speed dual clutch transmission ', '7-speed s-tronic',
#        '5-speed`', '9 speed tronic', '6-speed ivt', 'direct drive',
#        '6 speed ivt', 'ivt', '8 speed cvt',
#        'five speed manual transmission', '5 speed at+ paddle shifters',
#        '8-speed ', 'imt', 'ags', '6speed', '4-speed', '6 speed mt'],
#       dtype=object)

# %%
gb=[]
for i in list(df['gear_box']):
    if i=='5 speed' or i=='5-speed' or i=='5 speed ' or i=='5' or i=='five speed' :
        gb.append('5 speed')
    elif i=='five speed manual transmission gearbox' :
        gb.append('5 speed manual transmission')
    elif i=='five speed manual transmission':
        gb.append('5 speed manual transmission')
    elif i in ['7 speed ','7-speed']:
        gb.append('7 speed')
    elif i in ['7-speed stronic','7-speed s-tronic','7-speed s-tronic ']:
        gb.append('7-speed s-tronic')
    elif i in [ '7 speed dct','7-speed dct']:
        gb.append( '7 speed dct')
    elif i in ['8-speed','8', '8-speed ','8 speed ']:
        gb.append('8 speed')
    elif i in ['6 speed ','6-speed','6']:
        gb.append('6 speed')
    elif i in ['6-speed at','6-speed at' ,'6 speed at',]:
        gb.append('6-speed at')
    elif i in ['six speed manual',]:
        gb.append('6-speed manual') 
    else:
        gb.append(i)

# %%
df['gear_box']=gb
print(df['gear_box'].value_counts())
# Out:
# gear_box
# 5 speed                                            881
# 6 speed                                            282
# 7 speed                                             63
# 8 speed                                             48
# 4 speed                                             39
# cvt                                                 32
# nan                                                 24
# 7 speed dct                                         19
# 9 speed                                             15
# 5 speed cvt                                         11
# 6-speed imt                                          8
# 8-speed steptronic                                   6
# five speed manual                                    6
# 6 speed imt                                          5
# 8 speed tiptronic                                    4
# 7-speed s-tronic                                     4
# 7 speed dsg                                          3
# ags                                                  2
# imt                                                  2
# direct drive                                         2
# 5-speed`                                             2
# 6-speed dct                                          2
# 7 speed cvt                                          2
# 8-speed steptronic sport automatic transmission      2
# 9-speed                                              2
# 6-speed at                                           1
# 8 speed cvt                                          1
# 4-speed                                              1
# 6speed                                               1
# 6-speed autoshift                                    1
# 5 speed at+ paddle shifters                          1
# 5 speed manual transmission                          1
# ivt                                                  1
# 8g-dct                                               1
# 6 speed ivt                                          1
# 6-speed cvt                                          1
# 6-speed ivt                                          1
# 9 speed tronic                                       1
# 7g dct 7-speed dual clutch transmission              1
# 6 speed mt                                           1
# Name: count, dtype: int64

# %%
x=list(df['gear_box'])
gb1=['other' if x.count(i)<10 else i for i in x ]

# %%
df['gear_box']=gb1
print(df['gear_box'].value_counts())
# Out:
# gear_box
# 5 speed        881
# 6 speed        282
# other           67
# 7 speed         63
# 8 speed         48
# 4 speed         39
# cvt             32
# nan             24
# 7 speed dct     19
# 9 speed         15
# 5 speed cvt     11
# Name: count, dtype: int64

# %%
df.groupby(['body_type','gear_box'])['gear_box'].count().plot(kind='barh')
plt.show()

# %%
df.fillna({'gear_box':'5 speed'},inplace=True)

# %%
df['gear_box'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Engineering the 'Mileage' column

# %%
df['mileage']=df['Mileage'].apply(lambda x:str(x).lower())
print(df['mileage'].value_counts())
# Out:
# mileage
# 18.9 kmpl     72
# 22.38 kmpl    46
# 18.6 kmpl     44
# 21.4 kmpl     43
# nan           42
#               ..
# 11.57 kmpl     1
# 15.26 kmpl     1
# 13.79 kmpl     1
# 16.13 kmpl     1
# 21.8 kmpl      1
# Name: count, Length: 318, dtype: int64

# %%
avs=[]
for i in list(df['mileage']):
    if i=='nan':
        avs.append(np.nan)
    elif i[0].isnumeric()==True:
        b=[]
        for j in i:
                if j.isnumeric()==True or j=='.':
                    b.append(j)
        
        avs.append(round(float(''.join(b))))
df['mileage']=avs
df['mileage'].value_counts()
# Out:
# mileage
# 19.0     219
# 18.0     163
# 22.0     157
# 21.0     145
# 17.0     134
# 20.0     108
# 16.0     100
# 15.0      75
# 23.0      68
# 14.0      54
# 13.0      54
# 24.0      42
# 25.0      36
# 12.0      24
# 11.0      17
# 26.0      14
# 27.0      13
# 28.0       5
# 8.0        3
# 10.0       3
# 9.0        2
# 110.0      1
# 140.0      1
# 32.0       1
# Name: count, dtype: int64

# %%
sns.displot(df['mileage'])
plt.show()
print('mean:',df['mileage'].mean(),'median:',df['mileage'].median())
# Out:
# mean: 19.02084781097985 median: 19.0

# %%
df.fillna({'mileage':df['mileage'].median()},inplace=True)

# %%
df['mileage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Engineering the 'Wheel Base' column

# %%
df['wheel_base' ]=df['Wheel Base' ].apply(lambda x:str(x).lower())
print(df['wheel_base' ].value_counts())
# Out:
# wheel_base
# 2425mm     88
# 2450       75
# 2570mm     69
# 2520mm     68
# 2600mm     68
#            ..
# 3060        1
# 3105 mm     1
# 2975 mm     1
# 3014        1
# 2703 mm     1
# Name: count, Length: 176, dtype: int64

# %%
avs=[]
for i in list(df['wheel_base']):
    if i=='nan':
        avs.append(np.nan)
    elif i[0].isnumeric()==True:
        b=[]
        for j in i:
                if j.isnumeric()==True or j=='.':
                    b.append(j)
        
        avs.append(round(float(''.join(b))))
df['wheel_base']=avs
df['wheel_base'].value_counts()
# Out:
# wheel_base
# 2450.0    132
# 2425.0     88
# 2600.0     76
# 2520.0     71
# 2570.0     69
#          ...
# 2841.0      1
# 2467.0      1
# 2648.0      1
# 2010.0      1
# 2703.0      1
# Name: count, Length: 129, dtype: int64

# %%
sns.displot(df['wheel_base'])
plt.show()
print('mean:',df['wheel_base'].mean(),'median:',df['wheel_base'].median())
# Out:
# mean: 2551.9363762102353 median: 2520.0

# %%
df.fillna({'wheel_base':df['wheel_base'].median()},inplace=True)

# %%
df['wheel_base'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Engineering the 'Height' column

# %%
df['height' ]=df['Height'].apply(lambda x:str(x).lower())
print(df['height'].value_counts())
# Out:
# height
# 1505mm     81
# 1520mm     67
# 1510mm     58
# 1475mm     55
# 1530       53
#            ..
# 1490 mm     1
# 1616mm      1
# 1572mm      1
# 1465mm      1
# 1488 mm     1
# Name: count, Length: 223, dtype: int64

# %%
avs=[]
for i in list(df['height']):
    if i=='nan':
        avs.append(np.nan)
    elif i[0].isnumeric()==True:
        b=[]
        for j in i:
                if j.isnumeric()==True or j=='.':
                    b.append(j)
        
        avs.append(round(float(''.join(b[:4]))))
df['height']=avs
df['height'].value_counts()
# Out:
# height
# 1530.0    99
# 1505.0    90
# 1520.0    76
# 1510.0    58
# 1475.0    56
#           ..
# 1534.0     1
# 1670.0     1
# 1626.0     1
# 1651.0     1
# 1488.0     1
# Name: count, Length: 173, dtype: int64

# %%
sns.displot(df['height'])
plt.show()
print('mean:',df['height'].mean(),'median:',df['height'].median())
# Out:
# mean: 1570.1260273972603 median: 1530.0

# %%
df.fillna({'height':df['height'].median()},inplace=True)

# %% [markdown]
# ### Engineering the 'Kerb Weight' column

# %%
df['kerb_weight' ]=df['Kerb Weight'].apply(lambda x:str(x).lower())
print(df['kerb_weight'].value_counts())
df['kerb_weight'].unique()
# Out:
# kerb_weight
# 875-905    53
# 1066kg     39
# 1120       31
# 935kg      28
# 880kg      17
#            ..
# 1585        1
# 1085        1
# 1845        1
# 2000kg      1
# 1970kg      1
# Name: count, Length: 455, dtype: int64
# array(['835kg', '1242kg', '1012kg', '1180', '1230kg', '1551 kgs', '1070',
#        '1440', '1105', '870kg', '1200', '1066 kg', '1900', '1562 kgs',
#        '1675', '1120', '1315', '1049kg', '1600kg', '875-905', '2200kg',
#        '1050', '845', '1585', '1595kg', '1940', '1650', '1140', '885kg',
#        '1170 kg', '1655kg', '1955 kg', '1375', '1066kg', '1515kg',
#        '880kg', '1329kg', '1735kg', '762kg', '1990', '1250kg', '1535',
#        '1980', '705kg', '2535kg', '1825kg', '1060', '2345kg', '1970',
#        '750', '1305kg', '1095kg', '815', '1206kg', '1225kg', '1320',
#        '1700', '960kg', '850kg', '1720', '1105kg', '1360kg', '1376kg',
#        '980kg', '1015kg', '1260', '1380', '1192kg', '1025kg', '1040',
#        '1135', '1865', '890kg', '860kg', '730', '1652kg', '1835', '1345',
#        '1820', '925kg', '910-935', '760kg', '1086', '910', '1179kg',
#        '1525', '1730', '900', '1300', '1465', '2020', '1350kg', '840kg',
#        '1445kg', '1580', '1608kg', '960', '1100', '1830kg', '755', '1020',
#        '1879kg', '1040-1130kg', '855', '1670', '935kg', '2010', '947',
#        '930', '2060', '1455kg', '1537', '2360', '1745', '1238', '1954 kg',
#        '1390', '1285', '1080kg', '1109 kg', '1274kg', '1158kg', '1395',
#        '1585kg', '1885kg', '950kg', '1325', '1190kg', '1340', '1530',
#        '1240', '1296kg', '1042 kg', '1960', '1044kg', '1255', '985kg',
#        '880-915', '1235kg', '1042kg', '1107kg', '1250', '1115kg',
#        '1220kg', '1061kg', '1840', '1,240 kg', '1320kg', '1080', '825',
#        '1150kg', '1640kg', '1210kg', '1103kg', '2060kg', '1304kg',
#        '1800kg', '1060kg', '1680kg', '1030kg', '1175kg', '1780kg',
#        '1072kg', '1065', '1490kg', '1245-1280 kg', '1770', '1205',
#        '895kg', '1460kg', '855-885', '1450', '1039kg', '745', '784kg',
#        '1641 kgs', '1220', '860', '970kg', '1275', '1160', '1085kg',
#        '1125kg', '940kg', '1065kg', '1425kg', '860kgs', '1537 kgs',
#        '1290', '2195', '1205kg', '865kg', '1635', '1,350-1,540 kg',
#        '1330', '1540kg', '1240kg', '1890', '1720kg', '1045', '1660kg',
#        '1785', '1138kg', '1165kg', '1228kg', '2152', '1280', '1880kg',
#        '1675kg', '1300kg', '1055', '1195', '1106', '1288', '1640',
#        '1670 kg', '920-955', '1084kg', '810', '1155', '1210', '1061',
#        '1470', '1088kg', '1140kg', '736-775', '1725', '820', '1403kg',
#        '1915', '1010kg', '1064 kg', '1228', '770', '779kg', '1016-1044kg',
#        '830-845kg', '699', '1620', '990', '2014kg', '835', '865-890',
#        '910kg', '1715', '915kg', '1710', '1275kg', '1035-1062 kg',
#        '1,520', '1495', '1277kg', '1040kg', '1107-1153kg', '1775kg',
#        '1208', '1395kg', '1630kg', '1014', '1235', 'nan', '1604-1706 kg',
#        '1,310', '990kg', '1145kg', '860-895kg', '1053kg', '2095',
#        '1281kg', '835kgs', '2160kg', '2175kg', '1225', '1550',
#        '1115-1130', '1185kg', '1555', '1825', '1570kg', '1252kg', '930kg',
#        '1430', '1201', '1270', '1130', '1090kg', '785kg', '982', '1439kg',
#        '1703kg', '1036', '1400', '1150', '1238kg', '1790kg', '855kg',
#        '1184 kg', '1020kg', '1400kg', '845kg', '1590', '1700kg',
#        '955-990kg', '1290kg', '1835kg', '1520kg', '1450-1525kg', '1310kg',
#        '995kg', '920-940kg', '1035kg', '940', '1510', '765 kg', '2045',
#        '1121kg', '939', '1085', '1845', '2000kg', '1145 kg', '1795',
#        '1,550', '1155kg', '1625', '1525kg', '720kg', '1135kg', '1543kg',
#        '774kg', '1250-1255', '1650kg', '1010', '1265kg', '1100kg', '2370',
#        '1760kg', '1860', '1059kg', '982kg', '600kg', '945kg', '1139-1169',
#        '1086kg', '995-1015kg', '1351', '1070kg', '1100-1125kg', '1567kg',
#        '1025', '1095', '1,130 kg', '2000', '1740', '1598kg', '1755',
#        '1735', '1485', '1365-1372kg', '880', '1150-1205', '727kg', '1445',
#        '1630', '870', '1,750 kg', '1345kg', '710kg', '947kg',
#        '1160-1215kg', '1046', '960kgs', '1038-1047kg', '800kg', '1335',
#        '1280kg', '1,300', '1182kg', '1100 kg', '1055kg', '890',
#        '1650 kgs', '1066', '1773kg', '1180kg', '1,940 kg', '1085-1095kgs',
#        '710', '690', '1097kg', '1815', '1260kg', '1575kg', '1195-1255 kg',
#        '1565kg', '1660', '1030', '2240kg', '1135-1150', '1092kg', '825kg',
#        '1048kg', '990 kg', '920kg', '1155 kg', '900kg', '1610kg',
#        '1340kg', '765', '1790', '2040kg', '1545kg', '1475', '1258',
#        '1890kg', '1615kg', '1230', '1152kg', '1210-1240kg', '805-825kg',
#        '2200', '1685', '1036kg', '1430kg', '1865kg', '1570', '2145kg',
#        '1053-1080kg', '2500', '2230', '1309kg', '1135-1170', '2132kg',
#        '1760', '726-767', '1130-1170', '1355', '625', '1310', '830kg',
#        '757kg', '2115kg', '1350', '1110kg', '1173kg', '1246kg', '1535 kg',
#        '1200kg', '1690', '1795kg', '1415kg', '1575', '965kg', '1163kg',
#        '1970kg'], dtype=object)

# %%
avs=[]
for i in list(df['kerb_weight']):
    if i=='nan' or i=='kerb weight':
        avs.append(np.nan)
    
    elif i[0].isnumeric()==True:
        
        b=[]
        if '-' in list(i):
            r=i.index('-')
            for k in range(r):
                if i[k].isnumeric()==True or i[k]=='.':
                    b.append(i[k])
        else:   
            for j in i:
                    if j.isnumeric()==True or j=='.':
                        b.append(j)
        
        avs.append(round(float(''.join(b))))
df['kerb_weight']=avs
df['kerb_weight'].value_counts()
# Out:
# kerb_weight
# 875.0     53
# 1066.0    44
# 880.0     32
# 1120.0    31
# 935.0     28
#           ..
# 2160.0     1
# 2095.0     1
# 1380.0     1
# 1192.0     1
# 1163.0     1
# Name: count, Length: 319, dtype: int64

# %%
sns.displot(df['kerb_weight'])
plt.show()
print('mean:',df['kerb_weight'].mean(),'median:',df['kerb_weight'].median())
# Out:
# mean: 1202.4287661895023 median: 1105.0

# %%
df.fillna({'kerb_weight':df['kerb_weight'].median()},inplace=True)

# %% [markdown]
# ### Engineering the 'Length' column

# %%
df['length' ]=df['Length'].apply(lambda x:str(x).lower())
print(df['length'].value_counts())
df['length'].unique()
# Out:
# length
# 3995mm    153
# 3765mm     63
# 3985mm     59
# 4440mm     58
# 3845mm     53
#          ...
# 4629mm      1
# 3640mm      1
# 4815mm      1
# 3886mm      1
# 4107mm      1
# Name: count, Length: 242, dtype: int64
# array(['3715mm', '3998mm', '3746mm', '3995mm', '4300mm', '4395mm',
#        '3785mm', '3995 mm', '4490 mm', '3765mm', '3955 mm', '4585mm',
#        '4436mm', '3993', '4440mm', '4841mm', '3845mm', '4360', '5246mm',
#        '3610 mm', '3565mm', '5063mm', '4701mm', '4405mm', '3599mm',
#        '4395 mm', '4686mm', '4936mm', '4695 mm', '3985mm', '4530mm',
#        '4933mm', '3445mm', '4430mm', '3850mm', '4315mm', '5075mm',
#        '3495mm', '5120mm', '4661mm', '5089mm', '3731mm', '3994mm',
#        '3810mm', '3695mm', '4386mm', '4270mm', '4598mm', '3840mm',
#        '4824mm', '4490mm', '3955mm', '4498mm', '4670mm', '3775mm',
#        '3970mm', '4413mm', '3675mm', '4708', '3636mm', '3585mm', '3679mm',
#        '4635mm', '4720mm', '3610mm', '3620mm', '3991mm', '4390mm',
#        '4425mm', '4655mm', '4500mm', '4234mm', '4531mm', '4838mm',
#        '4629mm', '3530mm', '3940 mm', '4892mm', '3886mm', '3700mm',
#        '4886mm', '4520mm', '4475mm', '4795mm', '4598 mm', '4656 mm',
#        '4331mm', '3971mm', '4575mm', '4549mm', '4660mm', '5091mm',
#        '4329mm', '4265mm', '3999mm', '4384mm', '4,560 mm', '4852mm',
#        '4755mm', '4868mm', '4620mm', '4490', '4,140 mm', '4922 mm',
#        '4480mm', '4961mm', '3595mm', '4458mm', '4225mm', '4221mm',
#        '4323mm', '4250mm', '3545mm', '4359mm', '4375mm', '5115',
#        '4,572 mm', '4861mm', '4560mm', '4160mm', '4752 mm', 'nan',
#        '4580mm', '3714mm', '4600mm', '4705mm', '4,580 mm', '3990mm',
#        '3995', '3,565 mm', '4440', '4,586 mm', '4277mm', '3565', '4644mm',
#        '3429mm', '3655 mm', '4370mm', '5060mm', '3954mm', '4708mm',
#        '4388mm', '3795mm', '4915mm', '3992mm', '4699mm', '4726mm',
#        '4731mm', '4292mm', '4803 mm', '3765', '4655 mm', '4817mm',
#        '4819mm', '4658mm', '4630mm', '4545mm', '3590mm', '2974', '3370mm',
#        '4659mm', '4509mm', '3993mm', '3690mm', '4735mm', '3760mm',
#        '4439mm', '4597mm', '4815mm', '3989mm', '3640mm', '3675', '4695mm',
#        '3805mm', '4300 mm', '3535 mm', '4735', '4056mm', '4456', '4907mm',
#        '4950mm', '3395mm', '4222mm', '4296mm', '4435mm', '5150 mm',
#        '4247mm', '3981mm', '3099 mm', '4838 mm', '4788mm', '3801 mm',
#        '4290mm', '4,282 mm', '4657mm', '4833mm', '4859mm', '3987mm',
#        '4525mm', '4477mm', '3430mm', '4879mm', '4540mm', '4,838 mm',
#        '4648mm', '4305mm', '3099mm  ', '4541mm', '4420 mm', '4585 mm',
#        '4150 mm', '5247mm', '4,421 mm', '3988mm', '4596mm', '5067mm',
#        '3435mm', '4282mm', '4891mm', '3445', '3,827 mm', '4369mm',
#        '4591mm', '4650mm', '4769mm', '3920mm', '4324mm', '4000mm',
#        '4385mm', '4807mm', '4223mm', '4421mm', '4420mm', '4456mm',
#        '4985mm', '5115mm', '4300', '3780mm', '4299 mm', '4500', '4618 mm',
#        '4107mm'], dtype=object)

# %%
avs=[]
for i in list(df['length']):
    if i=='nan':
        avs.append(np.nan)
    elif i[0].isnumeric()==True:
        b=[]
        for j in i:
                if j.isnumeric()==True or j=='.':
                    b.append(j)
        
        avs.append(round(float(''.join(b[:4]))))
df['length']=avs
df['length'].value_counts()
# Out:
# length
# 3995.0    181
# 3765.0     65
# 4440.0     60
# 3985.0     59
# 3845.0     53
#          ...
# 4629.0      1
# 4815.0      1
# 3886.0      1
# 4475.0      1
# 4107.0      1
# Name: count, Length: 208, dtype: int64

# %%
sns.displot(df['length'])
plt.show()
print('mean:',df['length'].mean(),'median:',df['length'].median())
# Out:
# mean: 4112.510958904109 median: 3995.0

# %%
df.fillna({'length':df['length'].median()},inplace=True)

# %% [markdown]
# ### Engineering the 'Max Power' column

# %%
df['max_power']=df['Max Power'].apply(lambda x:str(x).lower())
print(df['max_power'].value_counts())
df['max_power'].unique()
# Out:
# max_power
# 88.50bhp     73
# 81.86bhp     58
# 81.80bhp     54
# 88.7bhp      49
# 83.1bhp      43
#              ..
# 281.61bhp     1
# 145hp         1
# 164.7bhp      1
# 89.84bhp      1
# 104.68        1
# Name: count, Length: 280, dtype: int64
# array(['67.04bhp', '121.31bhp', '84bhp', '81.86bhp', '88.5bhp', '170bhp',
#        '67bhp', '118.35bhp', '103.25bhp', '83.1bhp', '88.7bhp',
#        '83.83bhp', '140bhp', '187.74bhp', '88.76bhp', '117.3bhp', '177 ',
#        '88.50bhp', '104.55bhp', '453.26bhp', '68bhp', '62.1bhp',
#        '194.4bhp', '174.33bhp', '167.67bhp', '103bhp', '194bhp',
#        '248.08bhp', '171 ps ', '108.5bhp', '81.83bhp', '88.73bhp',
#        '147.5bhp', '47.33bhp', '120bhp', '189.08bhp', '138.08bhp',
#        '281.61bhp', '46.3bhp', '254.8bhp', '241.4bhp', '83 ps ',
#        '65.71bhp', '103.52bhp', '120.69bhp', '126.2bhp', '74bhp',
#        '188bhp', '178bhp', '85.80bhp', '118.36bhp', '116.3bhp',
#        '103.6bhp', '108.6bhp', '70bhp', '82.85bhp', '77bhp', '68.05bhp',
#        '190bhp', '141bhp', '86.8bhp', '81.80bhp', '67.1bhp', '71.01bhp',
#        '55.2bhp', '103.2bhp', '105.5bhp', '167.68bhp', '156.9bhp',
#        '121.3bhp', '138.12bhp', '147.94bhp', '170 ', '160.77bhp',
#        '138.1bhp', '78.9bhp', '102.57bhp', '174.3bhp',
#        '80 ps at 5200 rpm', '197bhp', '113.42bhp', '82bhp', '258bhp',
#        '181bhp', '182.46bhp', '174.5bhp', '108.45bhp', '117.6bhp',
#        '103.5bhp', '158.8bhp', '121.36bhp', '88.8bhp', '160.92bhp',
#        '130.1bhp', '194.3bhp', '254.79bhp', '100.5bhp', '83.8bhp',
#        '110.4bhp', '90 ps ', '98.6bhp', '184bhp', '98.96bhp', '203bhp',
#        '87.2bhp', '100.6bhp', '91.1bhp', '70 ', '261.50bhp', '115 ',
#        '187.7bhp', '108.62bhp', '143bhp', '113.98bhp', '215 ',
#        '108.49bhp', '93.7bhp', '67.05bhp', '167.62bhp', '85.8bhp',
#        '115bhp', '94 ps ', '73.9bhp', '83.14bhp', '120.7bhp', '197.2bhp',
#        '106', '177.46bhp', '112bhp', '218 ', '152.87bhp', '75.10bhp',
#        '168.5bhp', '102', '105.94bhp', '153.866bhp', '98.63bhp',
#        '113.45bhp', '187.40bhp', '98.59bhp', '113.18bhp', '102.53bhp',
#        '80 ', '117.60bhp', '163.2', '65bhp', '73.94bhp', '120.33bhp',
#        '94.93bhp', '67.06bhp', '126.32bhp', '153.86bhp', '261.49bhp',
#        '83.81bhp', '119.35bhp', '177bhp', '104.5bhp', 'nan', '84.82bhp',
#        '203.2bhp', '103.26bhp', '113.43bhp', '160bhp', '150bhp', '136bhp',
#        '187.4bhp', '25.4bhp', '41.42bhp', '70.02bhp', '35 bhp ',
#        '138.03bhp', '86.83bhp', '141.04bhp', '86.76bhp', '69bhp',
#        '163.7bhp', '71bhp', '163.60bhp', '127bhp', '100 bhp ', '88.2',
#        '61 ps ', '74.02bhp', '89.84bhp', '171.5bhp', '147.9bhp',
#        '164.7bhp', '145hp', '100bhp', '79.4bhp', '52.8bhp', '72.41bhp',
#        '174.33', '182.38bhp', '103.2 ps at 5500 rpm', '60 ps ', '148bhp',
#        '71.02bhp', '88 ps ', '78 ', '136.78bhp', '92',
#        '112bhp at 3800 rpm', '116.4bhp', '63bhp', '177.6bhp', '115.05bhp',
#        '167.6bhp', '47.3bhp', '61.68bhp', '86.63bhp', '85.7bhp',
#        '246.74bhp', '62bhp', '118.41bhp', '72.4bhp', '335.25bhp', '75',
#        '73.75bhp', '40bhp', '93 ps ', '80.46bhp', '35 bhp', '147.8bhp',
#        '161.6 ', '68', '101 ', '126.3bhp', '157.75bhp', '75.09bhp',
#        '75bhp', '112.2 ', '101.65bhp', '110bhp', '204bhp', '53.64bhp',
#        '138.05bhp', '260.0 ', '73.8bhp', '37.5bhp', '72bhp', '110.5bhp',
#        '118ps at 6,600 rpm', '130bhp', '121bhp', '70', '379.7bhp',
#        '70 bhp at 4000 rpm', '120 ', '86.7bhp', '53.26bhp', '84.8bhp',
#        '94 ', '126.24bhp', '68 ', '384.87bhp', '48.21bhp', '201.1bhp',
#        '57 ', '123.24bhp', '138bhp', '172.35bhp', '105bhp', '173bhp',
#        '84bhp3750rpm', '200bhp', '177.5bhp', '94.68bhp', '147.51bhp',
#        '245bhp', '99.23bhp', '158.79bhp', '197.26bhp', '118.3bhp',
#        '296bhp', '40.36bhp', '91.7bhp', '241.38bhp', '78 kw ', '104.68'],
#       dtype=object)

# %%
a=[]
for i in list(df['max_power']):
    if 'bhp' not in i:
        a.append(i)
print(set(a))
# Out:
# {'70', '70 ', '88.2', '83 ps ', '118ps at 6,600 rpm', '177 ', '120 ', '57 ', '145hp', '101 ', '94 ', '171 ps ', '106', '68', 'nan', '78 kw ', '174.33', '260.0 ', '75', '170 ', '163.2', '103.2 ps at 5500 rpm', '115 ', '93 ps ', '215 ', '61 ps ', '90 ps ', '88 ps ', '60 ps ', '218 ', '94 ps ', '104.68', '80 ', '80 ps at 5200 rpm', '92', '68 ', '102', '78 ', '112.2 ', '161.6 '}

# %%
avs=[]
for i in list(df['max_power']):
    if i=='nan':
        avs.append(np.nan)
    elif i=='66(90) / 4000' or i=='90(66) ':
        avs.append(65)
    elif i=='118ps at 6,600 rpm':
        avs.append(116.39)
    elif i=='105 ps at 5250 rpm':
        avs.append(103.56)
    elif i=='90ps at 4000rpm':
        avs.append(78.91)
    elif i=='80 ps at 5200 rpm':
        avs.append(99.77)
    elif i=='63 hp at 3200 rpm':
        avs.append(63)
    elif i[0].isnumeric()==True:
        b=[]
        for j in i:
                if j.isnumeric()==True or j=='.':
                    b.append(j)
        
        avs.append(round(float(''.join(b[:4]))))
df['max_power']=avs
df['max_power'].value_counts()
# Out:
# max_power
# 82.0      166
# 88.0       91
# 67.0       83
# 89.0       79
# 83.0       58
#          ...
# 148.0       1
# 1123.0      1
# 246.0       1
# 335.0       1
# 296.0       1
# Name: count, Length: 129, dtype: int64

# %%
sns.displot(df['max_power'])
plt.show()
print('mean:',df['max_power'].mean(),'median:',df['max_power'].median())
# Out:
# mean: 117.44948122866893 median: 89.0

# %%
df.fillna({'max_power':df['max_power'].median()},inplace=True)

# %% [markdown]
# ### Engineering the 'Max Torque' column

# %%
df['max_torque' ]=df['Max Torque'].apply(lambda x:str(x).lower())
print(df['max_torque' ].value_counts())
df['max_torque' ].unique()
# Out:
# max_torque
# 113nm@4400rpm          70
# 113nm@4200rpm          54
# 110nm@4800rpm          54
# 90nm@3500rpm           53
# 115nm@4000rpm          46
#                        ..
# 110nm                   1
# 70nm@1000rpm            1
# 226nm@4400rpm           1
# 400nm@2800rpm           1
# 145@4,100 (kgm@rpm)     1
# Name: count, Length: 288, dtype: int64
# array(['90nm@3500rpm', '150nm@4500rpm', '114nm@3500rpm',
#        '113.75nm@4000rpm', '200nm@1750rpm', '350nm@1750-2500rpm',
#        '104nm@4000rpm', '171.6nm@1500-4000rpm', '138nm@4400rpm',
#        '115nm@4000rpm', '110nm@4800rpm', '330nm@1600-2800rpm',
#        '400nm@1600-2600rpm', '219.6nm@1500-2750rpm', '170nm@1750-4000rpm',
#        '145nm@4600rpm', '35.7 @ 1,750-3,000 (kgm@rpm)', '113nm@4400rpm',
#        '142nm @ 4000rpm', '700nm@1800-3500rpm', '99nm@4500 rpm',
#        '96.1nm@3000rpm', '300nm@1600-4000rpm', '380nm@1750-2500rpm',
#        '400nm@1600-2800rpm', '350nm@1450-4800rpm',
#        '343 nm @ 1400-3400 rpm', '245nm@1750rpm', '114.7nm@4000rpm',
#        '219.7nm@1500-2750rpm', '177.5nm@4700rpm', '400nm@1750-3000rpm',
#        '69nm@3500rpm', '290nm@1800-2800rpm', '280nm@1250rpm',
#        '242nm@1500-3200rpm', '600nm@1200-3200rpm', '62nm@3000rpm',
#        '117nm@4000rpm', '619nm@1600-2400rpm', '550nm@1750-2750rpm',
#        '91nm@4250rpm', '260nm@1500-2750rpm', '115 nm @ 3200 rpm ',
#        '89nm@3500rpm', '250nm@1500-2500rpm', '149nm@4500rpm',
#        '259.9nm@1900-2750rpm', '190nm@2000rpm', '400nm@1750-2500rpm',
#        '250nm@1250-5000rpm', '114nm@4000rpm', '171.62nm@1500-4000rpm',
#        '146nm@4800rpm', '175nm@1500-4100rpm', '160nm@1500-2750rpm',
#        '113.7nm@4000rpm', '190nm@1750-2250rpm', '99.04nm@4500rpm',
#        '400nm', '620nm@1600-2400rpm', '200nm@2000-3500rpm',
#        '250nm@1600-3600rpm', '109nm@4500rpm', '113nm@4200rpm',
#        '96nm@3500rpm', '74.5nm@4000rpm', '140nm@4200rpm', '191nm@4500rpm',
#        '151nm@4850rpm', '250nm@1500-3500rpm',
#        '34.7 @ 1,750-3,000 (kgm@rpm)', '250nm@2500-4000rpm',
#        '320nm@1750-2500rpm', '111.8nm@4000rpm', '145nm@3750rpm ',
#        '11.4 kgm at 4,000 rpm', '470nm@1750-2500rpm', '112nm@4000rpm',
#        '250nm@1500-2750rpm', '111.7nm@4000rpm', '560nm@1500-3000rpm',
#        '380nm@1750-3000rpm', '400.11nm@1750-2750rpm',
#        '420nm@1400-2600rpm', '400nm@1400-2800rpm', '248nm@2250rpm',
#        '218nm@4200rpm', '230nm@1500-2500rpm', '250nm@1620-4000rpm',
#        '181nm@4000rpm', '436.4nm@1800-2500rpm', '400nm@1550-4400rpm',
#        '150nm@1700-4500rpm', '240nm@1750rpm', '200nm@1900rpm',
#        '320nm@1600-2800rpm', '259.87nm@1500-3000rpm', '140nm@4400rpm',
#        '115 nm @ 4500 rpm', '220nm@1500-2750rpm', '402nm@1600-3000rpm',
#        '205nm@1750-3250rpm', '500nm@1600-1800rpm', '205nm@1800-2800rpm',
#        '200nm@1200-3600rpm', '130nm@4000rpm', '10.7 @ 2,500 (kgm@rpm)',
#        '620nm@1500-2500rpm', '17.8 @ 4,250 (kgm@rpm)', '450nm@2000rpm',
#        '175nm@1750-4000rpm', '84nm@3500rpm', '172nm@1500-4000rpm',
#        '320nm@1750-3000rpm', '240.26nm@1500-2750rpm',
#        '178nm@1750-4500rpm', '25.1 @ 4,000 (kgm@rpm)', '144nm@4400rpm',
#        '124.5nm@3500rpm', '300nm@1500-2500rpm', '130 nm @ 3000 rpm ',
#        '180nm@2000rpm', '200nm@1250-4000rpm', '154.9nm@4200rpm',
#        '440nm@1750-2750rpm', '25.5@1,900 (kgm@rpm)', '250@1250-5000rpm',
#        '207nm@2200rpm', '620nm@2000-2500rpm',
#        '25.5 @ 2,750-4,250 (kgm@rpm)', '200nm@1400-3400rpm',
#        '360nm@1750-2800rpm', '240nm@1600-5000rpm ', '420nm@1750rpm',
#        '110nm@3000-4300rpm', '95nm@2950-3800rpm', '360nm@1400-3200rpm',
#        '20.4@1400-3400 (kgm@rpm)', '254nm @ 1600rpm',
#        '115nm@3500-3600rpm', '152nm@2200-4400rpm', '300nm',
#        '143.8nm@4500rpm', '148nm@3750rpm', '11.4 @ 4,000 (kgm@rpm)',
#        '22.9@1,950-4,700 (kgm@rpm)', '160nm@2000rpm',
#        '200nm@1500-4000rpm', '119nm@4250rpm', '259.8nm@1900-2750rpm',
#        '380nm@2500rpm', '215nm@1750-3000rpm', '215nm@1750-2500rpm',
#        '145nm@4300rpm', '430nm@1750-2500rpm', '160nm@2800-3600rpm',
#        '142nm@4000rpm', 'nan', '35.7@1,250 (kgm@rpm)', '153nm@3800rpm',
#        '110nm@3750rpm', '113nm@3300rpm', '145nm@3750rpm',
#        '320nm@1500-3000rpm', '114.73nm@4000rpm', '224nm@1500-2750rpm',
#        '620nm@1600rpm', '400nm@2800rpm', '144nm@4500rpm',
#        '250nm@1750-2500rpm', '300nm@1600-3000rpm', '226nm@4400rpm',
#        '70nm@1000rpm', '110nm', '102nm@4000rpm', '6.1 kgm @ 3000 rpm',
#        '320nm@1500-4100rpm', '250nm', '114.74nm@4200rpm',
#        '250nm@1500-3000rpm', '140nm@1800-3000rpm', '245nm@4000rpm',
#        '180.4nm@1750-2500rpm', '245nm', '13.1 kgm @ 4600 rpm',
#        '11.5@4,500 (kgm@rpm)', '204nm@2000-2750rpm', '360nm@1200-3400rpm',
#        '327nm@2600rpm', '224nm@4000rpm', '212nm@2000-4000rpm',
#        '240nm@1600-2800rpm', '108nm@4400rpm', '173nm@4000rpm',
#        '85nm@2500rpm', '109nm@4600rpm', '98nm@3000rpm', '400nm@2000rpm',
#        '450nm@1750-2800rpm', '113.8nm@4000rpm', '14.9 kgm at 3000 rpm',
#        '78 nm @ 4500 rpm ', '343nm@1400-2800rpm', '110 nm @ 3200 rpm',
#        '12.7 @ 2,700 (kgm@rpm)', '319nm@1800-2800rpm',
#        '130@2500(kgm@rpm)', '260 nm at 1800-2200 rpm',
#        '190nm@1750-3000rpm', '182.5nm@1500-1800rpm', '222nm@4300rpm',
#        '85nm@3000rpm', '121.5nm@4200rpm', '122nm@4000rpm',
#        '365@1200-4500rpm', '90.3nm@4200rpm', '113nm@4500rpm',
#        '171nm@1800rpm', '450nm@1500-5200rpm', '11@3,000 (kgm@rpm)',
#        '91nm@2500 rpm', '126 nm @ 3200 rpm', '115nm@3750rpm',
#        '4.8 kgm@3000 rpm', '240nm@1500-2750rpm', '195nm@1400-2200rpm',
#        '116nm@4750rpm', '25.2 @ 1,500â€“4,500 (kgm@rpm)',
#        '12.5@3,000 (kgm@rpm)', '14.9 @ 3,400 (kgm@rpm)',
#        '153nm@3750-3800rpm', '250nm@1500-4500rpm', '200nm@1400-2200rpm',
#        '197nm@1750rpm', '25 @ 1,800-2,800 (kgm@rpm)', '113.76nm@4000rpm',
#        '380nm@1750-2750rpm', '136.8nm@4400rpm', '72nm@4386rpm',
#        '35.0 @1,750 (kgm@rpm)', '380nm@2000rpm', '172.5 nm@1750rpm',
#        '219.6nm@1750-2750rpm', '51nm@4000+/-500rpm', '136nm@4250rpm',
#        '146nm at 4800 rpm', '300nm@1600-2800rpm', '300nm@1750-2500rpm',
#        '13.5@2,500 (kgm@rpm)', '515nm@3500rpm', '155 nm at 1600-2800 rpm',
#        '25.5 @ 1,500-3,000 (kgm@rpm)', '135nm@2500rpm', '72nm@4250rpm',
#        '200nm@2000rpm', '12.5 @ 3,500 (kgm@rpm)', '300nm@1250-3000rpm',
#        '259.87nm@1900-2750rpm', '42 @ 2,000 (kgm@rpm)',
#        '95nm@3000-4300rpm', '420nm@1600-2800rpm',
#        '16.3 @ 2,000 (kgm@rpm)', '520nm@2000-4200rpm', '190nm@1750rpm',
#        '9.4 @ 2,750 (kgm@rpm)', '132nm@3000rpm', '170nm@1800-2400rpm',
#        '219.66nm@1500-2750rpm', '180nm@1440-1500rpm',
#        '170nm@1400-4500rpm', '320nm@1700-2700rpm', '300nm@1200-4000rpm',
#        '247nm@1800-2000rpm', '220nm@1350-4300rpm', '420nm@1900-2800rpm',
#        '120nm@4250rpm', '540nm@1750-3000rpm', '373.5nm@1500-2400rpm',
#        '343nm@1400-3400rpm', '280nm@2400-2800rpm', '400nm@1500-4000rpm',
#        '60nm@3500rpm', '209nm@2000rpm', '280nm@1350rpm',
#        '500nm@1400-3250rpm', '240 nm @ 2000 rpm', '145@4,100 (kgm@rpm)'],
#       dtype=object)

# %%
s=[i if '15' in i else 'a' for i in list(df['max_torque'])]
s
# Out:
# ['a',
#  '150nm@4500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '171.6nm@1500-4000rpm',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '219.6nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '219.7nm@1500-2750rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '242nm@1500-3200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '260nm@1500-2750rpm',
#  '115 nm @ 3200 rpm ',
#  'a',
#  '250nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '171.62nm@1500-4000rpm',
#  'a',
#  '175nm@1500-4100rpm',
#  '250nm@1500-2500rpm',
#  '160nm@1500-2750rpm',
#  'a',
#  'a',
#  '219.6nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '242nm@1500-3200rpm',
#  'a',
#  '175nm@1500-4100rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  '219.6nm@1500-2750rpm',
#  '242nm@1500-3200rpm',
#  '171.6nm@1500-4000rpm',
#  'a',
#  '171.6nm@1500-4000rpm',
#  '250nm@1500-3500rpm',
#  'a',
#  'a',
#  'a',
#  '242nm@1500-3200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '560nm@1500-3000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2500rpm',
#  '175nm@1500-4100rpm',
#  'a',
#  '150nm@4500rpm',
#  '230nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '400nm@1550-4400rpm',
#  '115nm@4000rpm',
#  '150nm@1700-4500rpm',
#  'a',
#  'a',
#  'a',
#  '171.6nm@1500-4000rpm',
#  'a',
#  'a',
#  '150nm@4500rpm',
#  'a',
#  'a',
#  'a',
#  '259.87nm@1500-3000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  '250nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  '115 nm @ 4500 rpm',
#  '115 nm @ 4500 rpm',
#  '150nm@4500rpm',
#  '220nm@1500-2750rpm',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '620nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '172nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  '240.26nm@1500-2750rpm',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '219.6nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  '300nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '154.9nm@4200rpm',
#  'a',
#  '171.62nm@1500-4000rpm',
#  'a',
#  'a',
#  '250nm@1500-2500rpm',
#  'a',
#  'a',
#  '171.62nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '171.6nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '175nm@1500-4100rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2500rpm',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@3500-3600rpm',
#  '152nm@2200-4400rpm',
#  'a',
#  '250nm@1500-2500rpm',
#  '250nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '171.6nm@1500-4000rpm',
#  'a',
#  'a',
#  '172nm@1500-4000rpm',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  '150nm@4500rpm',
#  'a',
#  '200nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  '115 nm @ 3200 rpm ',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '200nm@1500-4000rpm',
#  'a',
#  '150nm@4500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '215nm@1750-3000rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '175nm@1500-4100rpm',
#  'a',
#  '250nm@1500-2500rpm',
#  '215nm@1750-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '400nm@1550-4400rpm',
#  '250nm@1500-2750rpm',
#  'a',
#  '150nm@4500rpm',
#  'a',
#  'a',
#  '215nm@1750-2500rpm',
#  'a',
#  'a',
#  'a',
#  '242nm@1500-3200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '154.9nm@4200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  '171.6nm@1500-4000rpm',
#  'a',
#  'a',
#  '250nm@1500-2500rpm',
#  '153nm@3800rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2500rpm',
#  'a',
#  '320nm@1500-3000rpm',
#  'a',
#  'a',
#  'a',
#  '224nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '259.87nm@1500-3000rpm',
#  '175nm@1500-4100rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '242nm@1500-3200rpm',
#  '250nm@1500-2500rpm',
#  '320nm@1500-3000rpm',
#  'a',
#  'a',
#  '224nm@1500-2750rpm',
#  '171.6nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '172nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '171.62nm@1500-4000rpm',
#  '250nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  '154.9nm@4200rpm',
#  '115 nm @ 3200 rpm ',
#  '219.7nm@1500-2750rpm',
#  'a',
#  '320nm@1500-4100rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-3000rpm',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-3000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '219.6nm@1500-2750rpm',
#  'a',
#  'a',
#  '115 nm @ 3200 rpm ',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '242nm@1500-3200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  '154.9nm@4200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  '250nm@1500-2500rpm',
#  '154.9nm@4200rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '320nm@1500-4100rpm',
#  'a',
#  '115 nm @ 4500 rpm',
#  'a',
#  '171.62nm@1500-4000rpm',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '153nm@3800rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '320nm@1500-3000rpm',
#  'a',
#  'a',
#  '219.7nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '182.5nm@1500-1800rpm',
#  '115 nm @ 4500 rpm',
#  'a',
#  '300nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '172nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '450nm@1500-5200rpm',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  '219.7nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@3750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '240nm@1500-2750rpm',
#  '115nm@4000rpm',
#  'a',
#  '250nm@1500-2500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '219.7nm@1500-2750rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  '154.9nm@4200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '154.9nm@4200rpm',
#  'a',
#  '153nm@3750-3800rpm',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  '250nm@1500-4500rpm',
#  'a',
#  'a',
#  '250nm@1500-4500rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '151nm@4850rpm',
#  'a',
#  '151nm@4850rpm',
#  '151nm@4850rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '250nm@1500-3500rpm',
#  'a',
#  '259.87nm@1500-3000rpm',
#  'a',
#  '172nm@1500-4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '240nm@1500-2750rpm',
#  'a',
#  '259.87nm@1500-3000rpm',
#  'a',
#  '242nm@1500-3200rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '115nm@4000rpm',
#  'a',
#  'a',
#  'a',
#  'a',
#  'a',
#  '320nm@1500-4100rpm',
#  'a',
#  'a',
#  ...]

# %%
avs=[]
for i in list(df['max_torque']):
    if i=='nan' :
        avs.append(np.nan)
    elif i=='11.4 kgm at 4,000 rpm':
        avs.append(round(111.79581))
    elif i=='22.4 kgm at 1750-2750rpm':
        avs.append(round(219.67))
    elif i=='13.5 kgm @ 4700 rpm':
        avs.append(round(132.38))
    elif i=='180 nm at 1440-1500rpm':
        avs.append(round(180))
    elif i=='13.5 kgm @ 4700 rpm':
        avs.append(round(219.87))
    elif i=='155 nm at 1600-2800 rpm':
        avs.append(round(155))  
    elif i=='210 / 1900':
        avs.append(round(210)) 
    elif i=='135 nm @ 2500 rpm ':
        avs.append(round(135)) 
    elif i=='148  nm @ 3500  rpm':
        avs.append(round(148))
    elif i=='146nm at 4800 rpm':
        avs.append(round(146))
    
    elif i[0].isnumeric()==True:
        b=[]
        if '@' in list(i):
            r=i.index('@')
            for k in range(r):
                if i[k].isnumeric()==True or i[k]=='.':
                    b.append(i[k])
        else:   
            for j in i:
                    if j.isnumeric()==True or j=='.':
                        b.append(j)
        
        avs.append(round(float(''.join(b))))
df['max_torque']=avs
df['max_torque'].value_counts()
# Out:
# max_torque
# 1.130000e+02    132
# 1.140000e+02    102
# 1.150000e+02     90
# 1.100000e+02     65
# 2.000000e+02     57
#                ...
# 7.800000e+01      1
# 3.190000e+02      1
# 2.601800e+10      1
# 1.820000e+02      1
# 2.090000e+02      1
# Name: count, Length: 135, dtype: int64

# %%
max(avs)
# Out:
# 26018002200

# %%
# sns.displot(df['max_torque'])
# plt.show()
print('mean:',df['max_torque'].mean(),'median:',df['max_torque'].median())
# Out:
# mean: 17759905.25324232 median: 140.0

# %%
df.fillna({'max_torque':df['max_torque'].median()},inplace=True)

# %% [markdown]
# ### Engineering the 'Width' column

# %%
df['width' ]=df['Width'].apply(lambda x:str(x).lower())
print(df['width'].value_counts())
df['width'].unique()
# Out:
# width
# 1695mm      74
# 1735        69
# 1660mm      67
# 1734mm      62
# 1745mm      59
#             ..
# 1,686 mm     1
# 1670         1
# 1725mm       1
# 2065mm       1
# 1813 mm      1
# Name: count, Length: 198, dtype: int64
# array(['1635mm', '1765mm', '1647mm', '1660mm', '1785mm', '1818mm',
#        '1770 mm', '1730 mm', '1745mm', '1694 mm', '1890mm', '2020mm',
#        '1710mm', '1811', '1695mm', '1846mm', '1735', '1822', '2130mm',
#        '1645 mm', '1525mm', '1860mm', '2040mm', '1495mm', '1735 mm',
#        '2126mm', '1840 mm', '1734mm', '1775mm', '1874mm', '1515mm',
#        '1817mm', '1727mm', '1800mm', '2065mm', '1475mm', '2141mm',
#        '1894mm', '2177mm', '1579mm', '1811mm', '1665mm', '1655', '1699mm',
#        '1780mm', '1735mm', '1828mm', '1730mm', '1694mm', '1751mm',
#        '1814mm', '1680mm', '1682mm', '1715mm', '2138', '1595mm', '2097mm',
#        '1821 mm', '1835mm', '1750', '1550mm', '1790mm', '1819mm',
#        '1822mm', '2089mm', '1490', '1710 mm', '1690mm', '1739', '1938mm',
#        '1850mm', '1855mm', '1894 mm', '1729mm', '1890 mm', '2000mm',
#        '1820mm', '1992mm', '1760mm', '1902mm', '1813mm', '1,730 mm',
#        '1900mm', '1854mm', '1776mm', '1730', '1,634 mm', '2218 mm',
#        '1877mm', '1796mm', '1809mm', '1670mm', '2010mm', '1700mm', '1985',
#        '1,769 mm', '1864mm', '1918 mm', 'nan', '1770mm', '1683mm',
#        '2173mm', '1840mm', '1,770 mm', '2034mm', '1745', '1790',
#        '1,595 mm', '1695', '1,772 mm', '1740mm', '1520', '1778mm',
#        '1560mm', '1704mm', '1620 mm', '1579', '1811 mm', '1788mm',
#        '1737mm', '1891mm', '2019mm', '2086mm', '1600mm', '1677mm',
#        '1842mm', '1748mm', '2175mm', '1831mm', '1758', '1765 mm', '1677',
#        '1965 mm', '1777 mm', '1575mm', '1505', '1758mm', '1410mm',
#        '1839mm', '1755', '1830mm', '1821mm', '1687mm', '1475', '2099mm',
#        '1680', '1695 mm', '1495 mm', '1830', '2195mm', '1694', '1608mm',
#        '1820', '2102mm', '1706mm', '1640mm', '1845mm', '1490mm', '1793mm',
#        '2075mm', '1733mm', '1703mm', '1817 mm', '1665 mm', '1,686 mm',
#        '1670', '1725mm', '2058mm', '2071mm', '1,817 mm', '2098mm',
#        '1739mm', '1752mm', '1866 mm', '2110mm', '1642mm', '1,780 mm',
#        '1620mm', '2091mm', '1574mm', '1686mm', '2129mm', '1515',
#        '1,620 mm', '1918mm', '1859mm', '1726mm', '1984mm', '2112mm',
#        '1960mm', '2047mm', '2184mm', '1926mm', '1785', '1734', '2220mm',
#        '1822 mm', '1813 mm'], dtype=object)

# %%
avs=[]
for i in list(df['width']):
    if i=='nan':
        avs.append(np.nan)
    elif i[0].isnumeric()==True:
        b=[]
        for j in i:
                if j.isnumeric()==True or j=='.':
                    b.append(j)
        
        avs.append(round(float(''.join(b[:4]))))
df['width']=avs
df['width'].value_counts()
# Out:
# width
# 1735.0    117
# 1695.0     80
# 1660.0     67
# 1734.0     63
# 1745.0     62
#          ...
# 2195.0      1
# 1727.0      1
# 1683.0      1
# 1769.0      1
# 2220.0      1
# Name: count, Length: 150, dtype: int64

# %%
sns.displot(df['width'])
plt.show()
print('mean:',df['width'].mean(),'median:',df['width'].median())
# Out:
# mean: 1739.0602739726028 median: 1735.0

# %%
df.fillna({'width':df['width'].median()},inplace=True)

# %%
df.head()
# Out:
#           bt      owner      oem Registration Year Engine Displacement  \
# 0  Hatchback  >2_owners   maruti              2015              998 cc
# 1        SUV   2_owners     ford          Feb 2018             1497 cc
# 2  Hatchback    1_owner     tata         Sept 2018             1199 cc
# 3      Sedan    1_owner  hyundai          Dec 2014             1197 cc
# 4        SUV    1_owner   maruti              2015             1248 cc
#
#    Seating Capacity Alloy Wheel Size Turbo Charger   Engine Front Brake Type  \
# 0               5.0              NaN            No   998 CC  Ventilated Disc
# 1               5.0               16            No  1497 CC  Ventilated Disc
# 2               5.0               14            No  1199 CC             Disc
# 3               5.0               14            No  1197 CC            Disc
# 4               5.0               16           Yes  1248 CC  Ventilated Disc
#
#    ...  front_brake_type gear_box mileage wheel_base  height kerb_weight  \
# 0  ...  ventilated discs  5 speed    23.0     2425.0  1565.0       835.0
# 1  ...  ventilated discs  5 speed    17.0     2519.0  1647.0      1242.0
# 2  ...        solid disc  5 speed    24.0     2400.0  1535.0      1012.0
# 3  ...        solid disc  5 speed    19.0     2425.0  1520.0      1180.0
# 4  ...  ventilated discs  5 speed    24.0     2600.0  1595.0      1230.0
#
#    length max_power max_torque   width
# 0  3715.0      67.0       90.0  1635.0
# 1  3998.0     121.0      150.0  1765.0
# 2  3746.0      84.0      114.0  1647.0
# 3  3995.0      82.0      114.0  1660.0
# 4  4300.0      88.0      200.0  1785.0
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Checking for null values on the newly engineered columns

# %%
pd.DataFrame({'dtypes':df.dtypes,'null_count':df.isnull().sum(),
              'unique_values':df.nunique(),
             'percent_of_null_values':df.isnull().mean()})
# Out:
#                       dtypes  null_count  unique_values  \
# bt                    object           0              8
# owner                 object           0              3
# oem                   object           0             17
# Registration Year     object           0            179
# Engine Displacement   object           4             95
# Seating Capacity     float64           1              7
# Alloy Wheel Size      object         452             16
# Turbo Charger         object         193              6
# Engine                object           3            105
# Front Brake Type      object          21             17
# Gear Box              object          24             56
# Height                object          21            222
# Kerb Weight           object          14            468
# Length                object          21            241
# Max Power             object          16            279
# Max Torque            object          16            306
# Mileage               object          42            317
# Rear Brake Type       object          21             16
# Wheel Base            object          35            175
# Width                 object          21            197
# kms                  float64           0            816
# price_new            float64           0            672
# No Door Numbers      float64           2              4
# No of Cylinder       float64           6              8
# Values per Cylinder  float64          11              5
# body_type             object           0              6
# registration_year     object           0             18
# seating_capacity      object           0              5
# engine_displacement  float64           0             95
# alloy_wheel_size      object           0             10
# turbo_charger         object           0              4
# front_brake_type      object           4              3
# gear_box              object           0             11
# mileage              float64           0             24
# wheel_base           float64           0            129
# height               float64           0            173
# kerb_weight          float64           0            319
# length               float64           0            208
# max_power            float64           0            129
# max_torque           float64           0            135
# width                float64           0            150
#
#                      percent_of_null_values
# bt                                 0.000000
# owner                              0.000000
# oem                                0.000000
# Registration Year                  0.000000
# Engine Displacement                0.002701
# Seating Capacity                   0.000675
# Alloy Wheel Size                   0.305199
# Turbo Charger                      0.130317
# Engine                             0.002026
# Front Brake Type                   0.014180
# Gear Box                           0.016205
# Height                             0.014180
# Kerb Weight                        0.009453
# Length                             0.014180
# Max Power                          0.010804
# Max Torque                         0.010804
# Mileage                            0.028359
# Rear Brake Type                    0.014180
# Wheel Base                         0.023633
# Width                              0.014180
# kms                                0.000000
# price_new                          0.000000
# No Door Numbers                    0.001350
# No of Cylinder                     0.004051
# Values per Cylinder                0.007427
# body_type                          0.000000
# registration_year                  0.000000
# seating_capacity                   0.000000
# engine_displacement                0.000000
# alloy_wheel_size                   0.000000
# turbo_charger                      0.000000
# front_brake_type                   0.002701
# gear_box                           0.000000
# mileage                            0.000000
# wheel_base                         0.000000
# height                             0.000000
# kerb_weight                        0.000000
# length                             0.000000
# max_power                          0.000000
# max_torque                         0.000000
# width                              0.000000

# %%
df.dropna(subset=['front_brake_type','Rear Brake Type','No of Cylinder','Values per Cylinder'],inplace=True)

# %% [markdown]
# These two columns namely 'No of Cylinder','Values per Cylinder' has null values ,so I'm dropping the rows considering these two columns as subset in the entire dataframe

# %%
pd.DataFrame({'dtypes':df.dtypes,'null_count':df.isnull().sum(),
              'unique_values':df.nunique(),
             'percent_of_null_values':df.isnull().mean()})
# Out:
#                       dtypes  null_count  unique_values  \
# bt                    object           0              8
# owner                 object           0              3
# oem                   object           0             16
# Registration Year     object           0            179
# Engine Displacement   object           1             92
# Seating Capacity     float64           0              7
# Alloy Wheel Size      object         447             16
# Turbo Charger         object         169              6
# Engine                object           1             99
# Front Brake Type      object           0             14
# Gear Box              object           0             56
# Height                object           0            217
# Kerb Weight           object           2            458
# Length                object           0            235
# Max Power             object           0            271
# Max Torque            object           0            295
# Mileage               object          30            312
# Rear Brake Type       object           0             14
# Wheel Base            object          14            172
# Width                 object           0            193
# kms                  float64           0            811
# price_new            float64           0            664
# No Door Numbers      float64           0              4
# No of Cylinder       float64           0              8
# Values per Cylinder  float64           0              5
# body_type             object           0              6
# registration_year     object           0             18
# seating_capacity      object           0              5
# engine_displacement  float64           0             92
# alloy_wheel_size      object           0             10
# turbo_charger         object           0              4
# front_brake_type      object           0              3
# gear_box              object           0             10
# mileage              float64           0             24
# wheel_base           float64           0            126
# height               float64           0            170
# kerb_weight          float64           0            316
# length               float64           0            202
# max_power            float64           0            124
# max_torque           float64           0            130
# width                float64           0            147
#
#                      percent_of_null_values
# bt                                 0.000000
# owner                              0.000000
# oem                                0.000000
# Registration Year                  0.000000
# Engine Displacement                0.000691
# Seating Capacity                   0.000000
# Alloy Wheel Size                   0.308915
# Turbo Charger                      0.116793
# Engine                             0.000691
# Front Brake Type                   0.000000
# Gear Box                           0.000000
# Height                             0.000000
# Kerb Weight                        0.001382
# Length                             0.000000
# Max Power                          0.000000
# Max Torque                         0.000000
# Mileage                            0.020733
# Rear Brake Type                    0.000000
# Wheel Base                         0.009675
# Width                              0.000000
# kms                                0.000000
# price_new                          0.000000
# No Door Numbers                    0.000000
# No of Cylinder                     0.000000
# Values per Cylinder                0.000000
# body_type                          0.000000
# registration_year                  0.000000
# seating_capacity                   0.000000
# engine_displacement                0.000000
# alloy_wheel_size                   0.000000
# turbo_charger                      0.000000
# front_brake_type                   0.000000
# gear_box                           0.000000
# mileage                            0.000000
# wheel_base                         0.000000
# height                             0.000000
# kerb_weight                        0.000000
# length                             0.000000
# max_power                          0.000000
# max_torque                         0.000000
# width                              0.000000

# %%
new_all_selected_features=['owner', 'oem','body_type', 'registration_year', 
    'alloy_wheel_size', 'turbo_charger', 'front_brake_type', 'gear_box',
   'Rear Brake Type','seating_capacity','kms', 'price_new', 'engine_displacement', 'mileage', 'wheel_base',
   'height', 'kerb_weight', 'length', 'max_power', 'max_torque','width']
for i in car_features:
    new_all_selected_features.append(i)

# %%
df=df[new_all_selected_features]
df.head()
# Out:
#        owner      oem  body_type registration_year alloy_wheel_size  \
# 0  >2_owners   maruti  hatchback              2015              r16
# 1   2_owners     ford        suv              2018              r16
# 2    1_owner     tata  hatchback              2018              r14
# 3    1_owner  hyundai      sedan              2014              r14
# 4    1_owner   maruti        suv              2015              r16
#
#   turbo_charger  front_brake_type gear_box Rear Brake Type seating_capacity  \
# 0            no  ventilated discs  5 speed            Drum              5.0
# 1            no  ventilated discs  5 speed            Drum              5.0
# 2            no        solid disc  5 speed            Drum              5.0
# 3            no        solid disc  5 speed            Drum              5.0
# 4           yes  ventilated discs  5 speed      Solid Disc              5.0
#
#    ...  wheel_base  height  kerb_weight  length  max_power  max_torque  \
# 0  ...      2425.0  1565.0        835.0  3715.0       67.0        90.0
# 1  ...      2519.0  1647.0       1242.0  3998.0      121.0       150.0
# 2  ...      2400.0  1535.0       1012.0  3746.0       84.0       114.0
# 3  ...      2425.0  1520.0       1180.0  3995.0       82.0       114.0
# 4  ...      2600.0  1595.0       1230.0  4300.0       88.0       200.0
#
#     width  No Door Numbers  No of Cylinder  Values per Cylinder
# 0  1635.0              5.0             3.0                  4.0
# 1  1765.0              4.0             3.0                  4.0
# 2  1647.0              5.0             3.0                  4.0
# 3  1660.0              4.0             4.0                  4.0
# 4  1785.0              5.0             4.0                  4.0
#
# [5 rows x 24 columns]

# %%
#categorical columns list
cc=[]
#numerical columns list
nc=[]
for i in df.columns:
    if df[i].dtype=='O':
        cc.append(i)
    else:
        nc.append(i)
print('categorical_columns:',cc)
print()
print('numerical_columns:',nc)
# Out:
# categorical_columns: ['owner', 'oem', 'body_type', 'registration_year', 'alloy_wheel_size', 'turbo_charger', 'front_brake_type', 'gear_box', 'Rear Brake Type', 'seating_capacity']
#
# numerical_columns: ['kms', 'price_new', 'engine_displacement', 'mileage', 'wheel_base', 'height', 'kerb_weight', 'length', 'max_power', 'max_torque', 'width', 'No Door Numbers', 'No of Cylinder', 'Values per Cylinder']

# %% [markdown]
# ### Finding outliers in categorical columns and replacing it with upper and lower limit values respectively

# %%
def plots(df, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

   # boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')
    plt.show()

# %%
for m in nc:
    plots(df, m)

# %%
def find_skewed_boundaries(df, variable, distance):

    # Calculating the boundaries outside which sit the outliers
    # for skewed distributions


    IQR = round(df[variable].quantile(0.75) - df[variable].quantile(0.25))

    lower_boundary = abs(round(df[variable].quantile(0.25) - (IQR * distance)))
    upper_boundary = abs(round(df[variable].quantile(0.75) + (IQR * distance)))

    return upper_boundary, lower_boundary

# %%
ul=[]
for v in nc:
    upper_limit, lower_limit = find_skewed_boundaries(df, v, 1.5)
    ul.append((v,upper_limit, lower_limit))

# %%
def replace_outlier(dataset,variable,upper_limit,lower_limit):
    dataset[variable]= np.where(dataset[variable] > upper_limit, upper_limit,
                       np.where(dataset[variable] < lower_limit, lower_limit, dataset[variable]))

# %%
for v1 in range(len(ul)):
    replace_outlier(df,ul[v1][0],ul[v1][1],ul[v1][2])

# %%
for m in nc:
    plots(df, m)

# %%
# for Q-Q plots
import scipy.stats as stats
from sklearn.preprocessing import FunctionTransformer

def diagnostic_plots(df, variable):

    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable

    plt.figure(figsize=(15, 6))

    # histogram
    plt.subplot(1, 2, 1)
    df[variable].hist(bins=30)
    plt.title(f"Histogram of {variable}")

    # q-q plot
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.title(f"Q-Q plot of {variable}")

    plt.show()

# %% [markdown]
# ### Changing the distribution of the 'price_new' and 'kms' columns

# %%
# with open-source packages
from sklearn.preprocessing import PowerTransformer

#transforming the ''price_new' column using "box-cox"
transformer1 = PowerTransformer(method="box-cox", standardize=False)
transformer1.fit(df[['price_new']])
# transformer1.set_output(transform="pandas")
df['price_new']= transformer1.transform(df[['price_new']])

diagnostic_plots(df, 'price_new')

#transforming the 'kms' column using "box-cox"
transformer2 = PowerTransformer(method="box-cox", standardize=False)
transformer2.fit(df[['kms']])
# transformer2.set_output(transform="pandas")
df['kms']= transformer2.transform(df[['kms']])

diagnostic_plots(df, 'kms')

# %%
from sklearn.model_selection import train_test_split

# for encoding with feature-engine
from feature_engine.encoding import MeanEncoder

# %%
s=new_all_selected_features.index('price_new')
s1=new_all_selected_features[s]

# Removing the 'price_new' column from 'new_all_selected_features' list
new_all_selected_features.pop(s)
new_all_selected_features
# Out:
# ['owner',
#  'oem',
#  'body_type',
#  'registration_year',
#  'alloy_wheel_size',
#  'turbo_charger',
#  'front_brake_type',
#  'gear_box',
#  'Rear Brake Type',
#  'seating_capacity',
#  'kms',
#  'engine_displacement',
#  'mileage',
#  'wheel_base',
#  'height',
#  'kerb_weight',
#  'length',
#  'max_power',
#  'max_torque',
#  'width',
#  'No Door Numbers',
#  'No of Cylinder',
#  'Values per Cylinder']

# %%
y=df[s1]
X=df[new_all_selected_features]


X_train, X_test, y_train, y_test = train_test_split(
    X,  # predictors
    y,  # target
    test_size=0.20,  # percentage of obs in test set
    random_state=0,
)  # seed to ensure reproducibility

X_train.shape, X_test.shape
# Out:
# ((1157, 23), (290, 23))

# %%
mean_enc = MeanEncoder(variables=cc) #cc- categorical columns

# %%
mean_enc.fit(X_train, y_train)
# Out:
# MeanEncoder(variables=['owner', 'oem', 'body_type', 'registration_year',
#                        'alloy_wheel_size', 'turbo_charger', 'front_brake_type',
#                        'gear_box', 'Rear Brake Type', 'seating_capacity'])

# %%
X_train = mean_enc.transform(X_train)
X_test = mean_enc.transform(X_test)

# let's explore the result
X_train.head()
# Out:
# C:\Users\Kavin\anaconda3\envs\car_dekho_mlproject\lib\site-packages\feature_engine\encoding\base_encoder.py:255: UserWarning: During the encoding, NaN values were introduced in the feature(s) Rear Brake Type.
#   warnings.warn(
#         owner       oem  body_type  registration_year  alloy_wheel_size  \
# 979  5.303634  5.361900   5.339465           5.321496          5.284042
# 187  5.283039  5.285175   5.293571           5.298859          5.284042
# 157  5.237374  5.286786   5.293571           5.290154          5.285048
# 685  5.283039  5.280152   5.260107           5.298859          5.284042
# 9    5.303634  5.283900   5.260107           5.306497          5.284042
#
#      turbo_charger  front_brake_type  gear_box  Rear Brake Type  \
# 979       5.325083          5.296485  5.329666         5.278048
# 187       5.269480          5.280467  5.312505         5.278048
# 157       5.325083          5.296485  5.265705         5.278048
# 685       5.269480          5.296485  5.265705         5.278048
# 9         5.269480          5.296485  5.265705         5.278048
#
#      seating_capacity  ...  wheel_base  height  kerb_weight  length  \
# 979          5.286253  ...      2500.0  1642.0       1351.0  3995.0
# 187          5.286253  ...      2600.0  1495.0       1107.0  4440.0
# 157          5.286253  ...      2552.0  1466.0       1206.0  4386.0
# 685          5.286253  ...      2570.0  1505.0       1066.0  3985.0
# 9            5.286253  ...      2400.0  1535.0       1012.0  3746.0
#
#      max_power  max_torque   width  No Door Numbers  No of Cylinder  \
# 979       99.0       240.0  1790.0              5.0             4.0
# 187      117.0       145.0  1695.0              4.0             4.0
# 157      103.0       250.0  1699.0              4.0             4.0
# 685       82.0       115.0  1734.0              5.0             4.0
# 9         84.0       114.0  1647.0              5.0             4.0
#
#      Values per Cylinder
# 979                  4.0
# 187                  4.0
# 157                  4.0
# 685                  4.0
# 9                    4.0
#
# [5 rows x 23 columns]

# %%
X_test.isnull().sum()
# Out:
# owner                  0
# oem                    0
# body_type              0
# registration_year      0
# alloy_wheel_size       0
# turbo_charger          0
# front_brake_type       0
# gear_box               0
# Rear Brake Type        1
# seating_capacity       0
# kms                    0
# engine_displacement    0
# mileage                0
# wheel_base             0
# height                 0
# kerb_weight            0
# length                 0
# max_power              0
# max_torque             0
# width                  0
# No Door Numbers        0
# No of Cylinder         0
# Values per Cylinder    0
# dtype: int64

# %%
X_test['price_new']=y_test
X_test.dropna(inplace=True)
X_test.isnull().sum()
# Out:
# owner                  0
# oem                    0
# body_type              0
# registration_year      0
# alloy_wheel_size       0
# turbo_charger          0
# front_brake_type       0
# gear_box               0
# Rear Brake Type        0
# seating_capacity       0
# kms                    0
# engine_displacement    0
# mileage                0
# wheel_base             0
# height                 0
# kerb_weight            0
# length                 0
# max_power              0
# max_torque             0
# width                  0
# No Door Numbers        0
# No of Cylinder         0
# Values per Cylinder    0
# price_new              0
# dtype: int64

# %%
y_test=X_test['price_new']
X_test=X_test[new_all_selected_features]
X_test.shape
# Out:
# (289, 23)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import HistGradientBoostingRegressor

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Let's train a linear model.

# Instantiate a linear model.
linreg = LinearRegression()

# Train the model.
linreg.fit(scaler.transform(X_train), y_train)

# Make predictions on the train set and calculate
# the mean squared error.
# print('Train set')
pred_train = linreg.predict(scaler.transform(X_train))
print('Linear Regression rmse: {}'.format(np.sqrt(mean_squared_error(y_train, pred_train))))
print('Linear Regression r2-score: {}'.format(r2_score(y_train, pred_train)))
# Make predictions on the test set and calculate
# the mean squared error.
print('Test set')
pred_test = linreg.predict(scaler.transform(X_test))
print('Linear Regression rmse: {}'.format(np.sqrt(mean_squared_error(y_test, pred_test))))
print('Linear Regression r2-score: {}'.format(r2_score(y_test, pred_test)))
print()
# Out:
# Linear Regression rmse: 0.01943004038017077
# Linear Regression r2-score: 0.8716254591753728
# Test set
# Linear Regression rmse: 0.0221026339545379
# Linear Regression r2-score: 0.8433739001634781

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
hr=HistGradientBoostingRegressor(learning_rate=0.05,max_leaf_nodes=300,max_depth=200,
                                               max_iter=1000,
                                               random_state=2023)
# Train the model.
hr.fit(scaler.fit_transform(X_train), y_train)

# Make predictions on the train set and calculate
# the mean squared error.
print('Train set')
pred_train = hr.predict(scaler.transform(X_train))
print('HistGradientBoostingRegressor rmse: {}'.format(np.sqrt(mean_squared_error(y_train, pred_train))))
print('HistGradientBoostingRegressor r2-score: {}'.format(r2_score(y_train, pred_train)))
# Make predictions on the test set and calculate
# the mean squared error.
print('Test set')
pred_test = hr.predict(scaler.transform(X_test))
print('HistGradientBoostingRegressor rmse: {}'.format(np.sqrt(mean_squared_error(y_test, pred_test))))
print('HistGradientBoostingRegressor r2-score: {}'.format(r2_score(y_test, pred_test)))
print()
# Out:
# Train set
# HistGradientBoostingRegressor rmse: 0.0023770342206901017
# HistGradientBoostingRegressor r2-score: 0.9980786682259842
# Test set
# HistGradientBoostingRegressor rmse: 0.014779676913216118
# HistGradientBoostingRegressor r2-score: 0.9299664805567027

# %% [markdown]
# ### Inverse transforming the target column and comparing the 'actual' and 'predicted' values

# %%
u1=pd.concat([y_train,y_test],axis=0)
u2=pd.concat([pd.Series(pred_train),pd.Series(pred_test)],axis=0)

pred=transformer1.inverse_transform(pd.DataFrame(u2,columns=['price_new']))
y= transformer1.inverse_transform(u1.values.reshape(-1, 1))
x=pd.DataFrame({'rv':list(y),'pv':list(pred)})
x['residuals']=(x['rv']-x['pv'])
x['error']=(((x['rv']-x['pv']))/(x['rv']))

x['residuals_cor']=[i[0] for i in x['residuals']]
x['error_cor']=[i[0] for i in x['error']]
x.head()
# Out:
# C:\Users\Kavin\anaconda3\envs\car_dekho_mlproject\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
#                      rv                    pv              residuals  \
# 0   [1327999.999999996]  [1320130.4629472638]    [7869.537052732194]
# 1   [941999.9999999981]   [942971.6109112488]   [-971.6109112506965]
# 2  [499999.99999999907]   [502758.6590477701]  [-2758.6590477710124]
# 3   [614999.9999999944]   [620178.0087604505]   [-5178.008760456112]
# 4   [584999.9999999971]   [596576.4755899643]  [-11576.475589967216]
#
#                       error  residuals_cor  error_cor
# 0     [0.00592585621440679]    7869.537053   0.005926
# 1  [-0.0010314340883765376]    -971.610911  -0.001031
# 2  [-0.0055173180955420354]   -2758.659048  -0.005517
# 3   [-0.008419526439766113]   -5178.008760  -0.008420
# 4   [-0.019788847162337222]  -11576.475590  -0.019789

# %%
x['residuals'].max(),x['residuals'].min()
# Out:
# (array([704465.37114398]), array([-365965.20678818]))

# %%
round(list(x['error'].max())[0],2),round(list(x['error'].min())[0],2)
# Out:
# (0.4, -0.6)

# %%
sns.histplot(x['residuals_cor'])
plt.show()

# %%
sns.boxplot(x['residuals_cor'])
plt.show()

# %%
x['residuals_cor'].describe()
# Out:
# count      1446.000000
# mean       2515.870838
# std       63301.090683
# min     -365965.206788
# 25%       -6538.935167
# 50%         -95.362483
# 75%        6906.469003
# max      704465.371144
# Name: residuals_cor, dtype: float64

# %% [markdown]
# ### From 248 features ,through various analysis and tests I used only 23 features to predict the 'price' of the cars.Hope the project results are good!!!
